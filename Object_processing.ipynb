# %%
import mne
import mne.viz
import numpy as np
import pandas as pd
import matplotlib
# %matplotlib inline

epochs = mne.read_epochs(
    "derivatives/preprocessed/epochs/sub-01_eeg_epo.fif",
    preload=True
)

print(epochs)
# Out:
# Reading /Users/lohwenliang/ds005811/derivatives/preprocessed/epochs/sub-01_eeg_epo.fif ...
#     Found the data of interest:
#         t =    -100.00 ...     800.00 ms
#         0 CTF compensation matrices available
# Adding metadata with 18 columns
# 4000 matching events found
# No baseline correction applied
# 0 projection items activated
# <EpochsFIF | 4000 events (all good), -0.1 – 0.8 s (baseline -0.1 – 0 s), ~427.7 MiB, data loaded, with metadata,
#  'stim_on': 4000>

# %%
epochs.info
# Out:
# <Info | 15 non-empty values
#  bads: []
#  ch_names: Fp1, Fpz, Fp2, AF3, AF4, F7, F5, F3, F1, Fz, F2, F4, F6, F8, ...
#  chs: 62 EEG
#  custom_ref_applied: True
#  description: Anonymized using a time shift to preserve age at acquisition
#  dig: 65 items (3 Cardinal, 62 EEG)
#  experimenter: mne_anonymize
#  file_id: 4 items (dict)
#  highpass: 0.1 Hz
#  line_freq: 50.0
#  lowpass: 40.0 Hz
#  meas_date: 2021-04-28 17:48:26 UTC
#  meas_id: 4 items (dict)
#  nchan: 62
#  projs: []
#  sfreq: 250.0 Hz
#  subject_info: <subject_info | his_id: sub-01, sex: 2, hand: 0>
# >

# %%
print(f"epochs.events: type = {type(epochs.events)}; shape = {epochs.events.shape}")
print(f"epochs.events_id: type = {type(epochs.event_id)}\n    {epochs.event_id}")
print(f"epochs.annotations: type = {type(epochs.annotations)}\n    {epochs.annotations}")
# Out:
# epochs.events: type = <class 'numpy.ndarray'>; shape = (4000, 3)
# epochs.events_id: type = <class 'dict'>
#     {'stim_on': 4}
# epochs.annotations: type = <class 'NoneType'>
#     None

# %%
# display metadata of epochs
print(epochs.metadata.columns)

print(epochs.metadata.head())

for col in epochs.metadata.columns:
    print("\n", col)
    print(epochs.metadata[col].unique()[:20])
# Out:
# Index(['event_name', 'task', 'subject', 'session', 'run', 'image_id',
#        'class_id', 'class', 'super_class', 'stim_is_animate',
#        'resp_is_animate', 'resp_is_right', 'RT', 'stim_is_face', 'face_score',
#        'face_score_max', 'face_area', 'face_area_max'],
#       dtype='str')
#   event_name      task  subject     session  run         image_id   class_id  \
# 0    stim_on  ImageNet        1  ImageNet01    1  n03594734_45507  n03594734
# 1    stim_on  ImageNet        1  ImageNet01    1    n02865351_847  n02865351
# 2    stim_on  ImageNet        1  ImageNet01    1   n01983481_8224  n01983481
# 3    stim_on  ImageNet        1  ImageNet01    1  n02841315_24983  n02841315
# 4    stim_on  ImageNet        1  ImageNet01    1   n04483307_1497  n04483307
#
#               class   super_class  stim_is_animate  resp_is_animate  \
# 0              jean      covering            False            False
# 1          bolo tie      covering            False            False
# 2  American lobster  invertebrate             True             True
# 3        binoculars        device            False             True
# 4          trimaran    conveyance            False            False
#
#    resp_is_right        RT  stim_is_face    face_score  face_score_max  \
# 0           True  0.909161         False             0            0.00
# 1           True  0.193727         False             0            0.00
# 2           True  1.224706         False             0            0.00
# 3          False  1.098325          True  [0.80938494]            0.81
# 4           True  0.996995         False             0            0.00
#
#     face_area  face_area_max
# 0           0           0.00
# 1           0           0.00
# 2           0           0.00
# 3  [41602.21]       41602.21
# 4           0           0.00
#
#  event_name
# <StringArray>
# ['stim_on']
# Length: 1, dtype: str
#
#  task
# <StringArray>
# ['ImageNet']
# Length: 1, dtype: str
#
#  subject
# [1]
#
#  session
# <StringArray>
# ['ImageNet01', 'ImageNet02', 'ImageNet03', 'ImageNet04']
# Length: 4, dtype: str
#
#  run
# [1 2 3 4 5 6 7 8]
#
#  image_id
# <StringArray>
# ['n03594734_45507',   'n02865351_847',  'n01983481_8224', 'n02841315_24983',
#   'n04483307_1497', 'n04125021_15969',  'n01855032_8276',  'n04009552_6399',
#   'n02091244_4086', 'n02328150_18962', 'n03697007_17431',  'n03345487_2091',
#  'n09193705_36961',  'n02641379_3392',   'n07693725_990',  'n03877845_2504',
#   'n02130308_1943',  'n02108422_5316', 'n02120505_10346',  'n03868863_3250']
# Length: 20, dtype: str
#
#  class_id
# <StringArray>
# ['n03594734', 'n02865351', 'n01983481', 'n02841315', 'n04483307', 'n04125021',
#  'n01855032', 'n04009552', 'n02091244', 'n02328150', 'n03697007', 'n03345487',
#  'n09193705', 'n02641379', 'n07693725', 'n03877845', 'n02130308', 'n02108422',
#  'n02120505', 'n03868863']
# Length: 20, dtype: str
#
#  class
# <StringArray>
# [                  'jean',               'bolo tie',       'American lobster',
#              'binoculars',               'trimaran',                   'safe',
#  'red-breasted merganser',              'projector',           'Ibizan hound',
#                  'Angora',             'lumbermill',            'fire engine',
#                     'alp',                    'gar',                  'bagel',
#                  'palace',                'cheetah',           'bull mastiff',
#                'grey fox',            'oxygen mask']
# Length: 20, dtype: str
#
#  super_class
# <StringArray>
# [            'covering',         'invertebrate',               'device',
#            'conveyance',            'container',                 'bird',
#                'canine',               'mammal',            'structure',
#  'geological_formation',                 'fish',                 'food',
#                'feline',            'amphibian',            'carnivore',
#               'reptile',             'artifact',             'ungulate',
#             'equipment',                'fruit']
# Length: 20, dtype: str
#
#  stim_is_animate
# [False  True]
#
#  resp_is_animate
# [False  True]
#
#  resp_is_right
# [ True False]
#
#  RT
# [0.90916119 0.19372724 1.2247064  1.098325   0.99699505 0.90377879
#  1.07910998 1.220237   1.27775447 1.14502604 1.09715988 1.19094685
#  1.1195576  1.17148799 1.08050222 1.1044116  1.10156096 1.14499684
#  1.01068879 1.08457355]
#
#  stim_is_face
# [False  True]
#
#  face_score
# <StringArray>
# [                                                         '0',
#                                                '[0.80938494]',
#                                                 '[0.6863749]',
#  '[0.80237657, 0.7840212, 0.77802175, 0.7436546, 0.70574784]',
#                                                 '[0.7083171]',
#                          '[0.78325325, 0.76551276, 0.644193]',
#   '[0.85477376, 0.8260376, 0.80514216, 0.5641133, 0.5625958]',
#                                                '[0.86414385]',
#  '[0.8260688, 0.7806771, 0.77712995, 0.77035666, 0.73227227]',
#                                      '[0.8570443, 0.8497337]',
#                                                 '[0.5756804]',
#                                                '[0.88030005]',
#                                                '[0.78347373]',
#                                                 '[0.8213961]',
#                                                 '[0.8596953]',
#                                                 '[0.8386535]',
#                                      '[0.7836576, 0.6763052]',
#                                                '[0.57179844]',
#                                                '[0.88149726]',
#                                                 '[0.5270642]']
# Length: 20, dtype: str
#
#  face_score_max
# [0.   0.81 0.69 0.8  0.71 0.78 0.85 0.86 0.83 0.58 0.88 0.82 0.84 0.57
#  0.53 0.7  0.72 0.66 0.65 0.79]
#
#  face_area
# <StringArray>
# [                                                      '0',
#                                               '[41602.21]',
#                                              '[45890.273]',
#    '[536.42255, 484.2139, 513.2878, 447.01413, 288.52994]',
#                                              '[10473.233]',
#                         '[479.4517, 475.15063, 369.12292]',
#   '[775.2659, 1187.1272, 768.92004, 347.59467, 183.49968]',
#                                               '[733.0409]',
#  '[414.51712, 428.54263, 479.38464, 325.13635, 219.33333]',
#                                    '[3845.2087, 3438.188]',
#                                              '[537.25836]',
#                                               '[5995.952]',
#                                               '[6860.883]',
#                                              '[3304.8667]',
#                                              '[4346.4873]',
#                                               '[542.9161]',
#                                   '[1524.2164, 2570.1616]',
#                                              '[4934.5527]',
#                                              '[4253.4253]',
#                                              '[335.25006]']
# Length: 20, dtype: str
#
#  face_area_max
# [    0.   41602.21 45890.27   536.42 10473.23   479.45  1187.13   733.04
#    479.38  3845.21   537.26  5995.95  6860.88  3304.87  4346.49   542.92
#   2570.16  4934.55  4253.43   335.25]

# %%
# %cat sub-01/ses-ImageNet01/eeg/sub-01_ses-ImageNet01_task-ImageNet_run-01_events.tsv
# Out:
# onset	duration	trial_type	value	sample	StimulusPresentation
# 0.0	0.002	begin	1	0	PsychophysicsToolbox
# 0.498	0.002	stim_on	4	249	PsychophysicsToolbox
# 1.3	0.002	resp	3	650	PsychophysicsToolbox
# 1.314	0.002	resp	3	657	PsychophysicsToolbox
# 1.324	0.002	resp	3	662	PsychophysicsToolbox
# 1.34	0.002	resp	3	670	PsychophysicsToolbox
# 1.35	0.002	resp	3	675	PsychophysicsToolbox
# 1.36	0.002	resp	3	680	PsychophysicsToolbox
# 1.37	0.002	resp	3	685	PsychophysicsToolbox
# 1.38	0.002	resp	3	690	PsychophysicsToolbox
# 1.39	0.002	resp	3	695	PsychophysicsToolbox
# 1.406	0.002	resp	3	703	PsychophysicsToolbox
# 2.068	0.002	stim_on	4	1034	PsychophysicsToolbox
# 2.16	0.002	resp	3	1080	PsychophysicsToolbox
# 2.184	0.002	resp	3	1092	PsychophysicsToolbox
# 2.194	0.002	resp	3	1097	PsychophysicsToolbox
# 2.204	0.002	resp	3	1102	PsychophysicsToolbox
# 2.214	0.002	resp	3	1107	PsychophysicsToolbox
# 2.224	0.002	resp	3	1112	PsychophysicsToolbox
# 2.24	0.002	resp	3	1120	PsychophysicsToolbox
# 2.25	0.002	resp	3	1125	PsychophysicsToolbox
# 2.26	0.002	resp	3	1130	PsychophysicsToolbox
# 3.538	0.002	stim_on	4	1769	PsychophysicsToolbox
# 4.66	0.002	resp	3	2330	PsychophysicsToolbox
# 4.674	0.002	resp	3	2337	PsychophysicsToolbox
# 4.684	0.002	resp	3	2342	PsychophysicsToolbox
# 4.7	0.002	resp	3	2350	PsychophysicsToolbox
# 4.71	0.002	resp	3	2355	PsychophysicsToolbox
# 4.72	0.002	resp	3	2360	PsychophysicsToolbox
# 4.73	0.002	resp	3	2365	PsychophysicsToolbox
# 4.74	0.002	resp	3	2370	PsychophysicsToolbox
# 4.75	0.002	resp	3	2375	PsychophysicsToolbox
# 4.76	0.002	resp	3	2380	PsychophysicsToolbox
# 5.258	0.002	stim_on	4	2629	PsychophysicsToolbox
# 6.26	0.002	resp	3	3130	PsychophysicsToolbox
# 6.278	0.002	resp	3	3139	PsychophysicsToolbox
# 6.288	0.002	resp	3	3144	PsychophysicsToolbox
# 6.298	0.002	resp	3	3149	PsychophysicsToolbox
# 6.308	0.002	resp	3	3154	PsychophysicsToolbox
# 6.318	0.002	resp	3	3159	PsychophysicsToolbox
# 6.328	0.002	resp	3	3164	PsychophysicsToolbox
# 6.338	0.002	resp	3	3169	PsychophysicsToolbox
# 6.354	0.002	resp	3	3177	PsychophysicsToolbox
# 6.66	0.002	stim_on	4	3330	PsychophysicsToolbox
# 7.546	0.002	resp	3	3773	PsychophysicsToolbox
# 7.564	0.002	resp	3	3782	PsychophysicsToolbox
# 7.574	0.002	resp	3	3787	PsychophysicsToolbox
# 7.584	0.002	resp	3	3792	PsychophysicsToolbox
# 7.594	0.002	resp	3	3797	PsychophysicsToolbox
# 7.61	0.002	resp	3	3805	PsychophysicsToolbox
# 7.62	0.002	resp	3	3810	PsychophysicsToolbox
# 7.63	0.002	resp	3	3815	PsychophysicsToolbox
# 7.64	0.002	resp	3	3820	PsychophysicsToolbox
# 7.65	0.002	resp	3	3825	PsychophysicsToolbox
# 7.66	0.002	resp	3	3830	PsychophysicsToolbox
# 8.246	0.002	stim_on	4	4123	PsychophysicsToolbox
# 9.038	0.002	resp	3	4519	PsychophysicsToolbox
# 9.052	0.002	resp	3	4526	PsychophysicsToolbox
# 9.062	0.002	resp	3	4531	PsychophysicsToolbox
# 9.072	0.002	resp	3	4536	PsychophysicsToolbox
# 9.082	0.002	resp	3	4541	PsychophysicsToolbox
# 9.098	0.002	resp	3	4549	PsychophysicsToolbox
# 9.108	0.002	resp	3	4554	PsychophysicsToolbox
# 9.118	0.002	resp	3	4559	PsychophysicsToolbox
# 9.128	0.002	resp	3	4564	PsychophysicsToolbox
# 9.138	0.002	resp	3	4569	PsychophysicsToolbox
# 9.148	0.002	resp	3	4574	PsychophysicsToolbox
# 9.798	0.002	stim_on	4	4899	PsychophysicsToolbox
# 10.772	0.002	resp	3	5386	PsychophysicsToolbox
# 10.79	0.002	resp	3	5395	PsychophysicsToolbox
# 10.806	0.002	resp	3	5403	PsychophysicsToolbox
# 10.816	0.002	resp	3	5408	PsychophysicsToolbox
# 10.826	0.002	resp	3	5413	PsychophysicsToolbox
# 10.836	0.002	resp	3	5418	PsychophysicsToolbox
# 10.846	0.002	resp	3	5423	PsychophysicsToolbox
# 10.856	0.002	resp	3	5428	PsychophysicsToolbox
# 10.866	0.002	resp	3	5433	PsychophysicsToolbox
# 10.876	0.002	resp	3	5438	PsychophysicsToolbox
# 11.268	0.002	stim_on	4	5634	PsychophysicsToolbox
# 12.388	0.002	resp	3	6194	PsychophysicsToolbox
# 12.406	0.002	resp	3	6203	PsychophysicsToolbox
# 12.416	0.002	resp	3	6208	PsychophysicsToolbox
# 12.426	0.002	resp	3	6213	PsychophysicsToolbox
# 12.436	0.002	resp	3	6218	PsychophysicsToolbox
# 12.446	0.002	resp	3	6223	PsychophysicsToolbox
# 12.456	0.002	resp	3	6228	PsychophysicsToolbox
# 12.466	0.002	resp	3	6233	PsychophysicsToolbox
# 12.482	0.002	resp	3	6241	PsychophysicsToolbox
# 12.492	0.002	resp	3	6246	PsychophysicsToolbox
# 12.638	0.002	stim_on	4	6319	PsychophysicsToolbox
# 13.77	0.002	resp	3	6885	PsychophysicsToolbox
# 13.782	0.002	resp	3	6891	PsychophysicsToolbox
# 13.798	0.002	resp	3	6899	PsychophysicsToolbox
# 13.808	0.002	resp	3	6904	PsychophysicsToolbox
# 13.818	0.002	resp	3	6909	PsychophysicsToolbox
# 13.828	0.002	resp	3	6914	PsychophysicsToolbox
# 13.838	0.002	resp	3	6919	PsychophysicsToolbox
# 13.848	0.002	resp	3	6924	PsychophysicsToolbox
# 13.858	0.002	resp	3	6929	PsychophysicsToolbox
# 13.868	0.002	resp	3	6934	PsychophysicsToolbox
# 13.878	0.002	resp	3	6939	PsychophysicsToolbox
# 13.888	0.002	resp	3	6944	PsychophysicsToolbox
# 13.898	0.002	resp	3	6949	PsychophysicsToolbox
# 13.908	0.002	resp	3	6954	PsychophysicsToolbox
# 13.918	0.002	resp	3	6959	PsychophysicsToolbox
# 13.956	0.002	stim_on	4	6978	PsychophysicsToolbox
# 14.956	0.002	resp	3	7478	PsychophysicsToolbox
# 14.974	0.002	resp	3	7487	PsychophysicsToolbox
# 14.984	0.002	resp	3	7492	PsychophysicsToolbox
# 14.994	0.002	resp	3	7497	PsychophysicsToolbox
# 15.004	0.002	resp	3	7502	PsychophysicsToolbox
# 15.014	0.002	resp	3	7507	PsychophysicsToolbox
# 15.024	0.002	resp	3	7512	PsychophysicsToolbox
# 15.034	0.002	resp	3	7517	PsychophysicsToolbox
# 15.044	0.002	resp	3	7522	PsychophysicsToolbox
# 15.054	0.002	resp	3	7527	PsychophysicsToolbox
# 15.064	0.002	resp	3	7532	PsychophysicsToolbox
# 15.074	0.002	resp	3	7537	PsychophysicsToolbox
# 15.09	0.002	resp	3	7545	PsychophysicsToolbox
# 15.1	0.002	resp	3	7550	PsychophysicsToolbox
# 15.442	0.002	stim_on	4	7721	PsychophysicsToolbox
# 16.424	0.002	resp	3	8212	PsychophysicsToolbox
# 16.442	0.002	resp	3	8221	PsychophysicsToolbox
# 16.452	0.002	resp	3	8226	PsychophysicsToolbox
# 16.462	0.002	resp	3	8231	PsychophysicsToolbox
# 16.472	0.002	resp	3	8236	PsychophysicsToolbox
# 16.488	0.002	resp	3	8244	PsychophysicsToolbox
# 16.498	0.002	resp	3	8249	PsychophysicsToolbox
# 16.508	0.002	resp	3	8254	PsychophysicsToolbox
# 16.518	0.002	resp	3	8259	PsychophysicsToolbox
# 16.528	0.002	resp	3	8264	PsychophysicsToolbox
# 16.538	0.002	resp	3	8269	PsychophysicsToolbox
# 16.828	0.002	stim_on	4	8414	PsychophysicsToolbox
# 17.908	0.002	resp	3	8954	PsychophysicsToolbox
# 17.922	0.002	resp	3	8961	PsychophysicsToolbox
# 17.932	0.002	resp	3	8966	PsychophysicsToolbox
# 17.942	0.002	resp	3	8971	PsychophysicsToolbox
# 17.952	0.002	resp	3	8976	PsychophysicsToolbox
# 17.962	0.002	resp	3	8981	PsychophysicsToolbox
# 17.972	0.002	resp	3	8986	PsychophysicsToolbox
# 17.982	0.002	resp	3	8991	PsychophysicsToolbox
# 17.992	0.002	resp	3	8996	PsychophysicsToolbox
# 18.002	0.002	resp	3	9001	PsychophysicsToolbox
# 18.018	0.002	resp	3	9009	PsychophysicsToolbox
# 18.432	0.002	stim_on	4	9216	PsychophysicsToolbox
# 19.436	0.002	resp	3	9718	PsychophysicsToolbox
# 19.454	0.002	resp	3	9727	PsychophysicsToolbox
# 19.464	0.002	resp	3	9732	PsychophysicsToolbox
# 19.474	0.002	resp	3	9737	PsychophysicsToolbox
# 19.484	0.002	resp	3	9742	PsychophysicsToolbox
# 19.494	0.002	resp	3	9747	PsychophysicsToolbox
# 19.504	0.002	resp	3	9752	PsychophysicsToolbox
# 19.514	0.002	resp	3	9757	PsychophysicsToolbox
# 19.524	0.002	resp	3	9762	PsychophysicsToolbox
# 19.534	0.002	resp	3	9767	PsychophysicsToolbox
# 19.544	0.002	resp	3	9772	PsychophysicsToolbox
# 19.554	0.002	resp	3	9777	PsychophysicsToolbox
# 19.9	0.002	stim_on	4	9950	PsychophysicsToolbox
# 20.936	0.002	resp	3	10468	PsychophysicsToolbox
# 20.95	0.002	resp	3	10475	PsychophysicsToolbox
# 20.96	0.002	resp	3	10480	PsychophysicsToolbox
# 20.97	0.002	resp	3	10485	PsychophysicsToolbox
# 20.98	0.002	resp	3	10490	PsychophysicsToolbox
# 20.99	0.002	resp	3	10495	PsychophysicsToolbox
# 21.0	0.002	resp	3	10500	PsychophysicsToolbox
# 21.01	0.002	resp	3	10505	PsychophysicsToolbox
# 21.02	0.002	resp	3	10510	PsychophysicsToolbox
# 21.03	0.002	resp	3	10515	PsychophysicsToolbox
# 21.04	0.002	resp	3	10520	PsychophysicsToolbox
# 21.05	0.002	resp	3	10525	PsychophysicsToolbox
# 21.06	0.002	resp	3	10530	PsychophysicsToolbox
# 21.07	0.002	resp	3	10535	PsychophysicsToolbox
# 21.554	0.002	stim_on	4	10777	PsychophysicsToolbox
# 22.538	0.002	resp	3	11269	PsychophysicsToolbox
# 22.552	0.002	resp	3	11276	PsychophysicsToolbox
# 22.562	0.002	resp	3	11281	PsychophysicsToolbox
# 22.572	0.002	resp	3	11286	PsychophysicsToolbox
# 22.582	0.002	resp	3	11291	PsychophysicsToolbox
# 22.592	0.002	resp	3	11296	PsychophysicsToolbox
# 22.602	0.002	resp	3	11301	PsychophysicsToolbox
# 22.612	0.002	resp	3	11306	PsychophysicsToolbox
# 22.628	0.002	resp	3	11314	PsychophysicsToolbox
# 22.638	0.002	resp	3	11319	PsychophysicsToolbox
# 23.156	0.002	stim_on	4	11578	PsychophysicsToolbox
# 24.116	0.002	resp	3	12058	PsychophysicsToolbox
# 24.134	0.002	resp	3	12067	PsychophysicsToolbox
# 24.144	0.002	resp	3	12072	PsychophysicsToolbox
# 24.154	0.002	resp	3	12077	PsychophysicsToolbox
# 24.164	0.002	resp	3	12082	PsychophysicsToolbox
# 24.174	0.002	resp	3	12087	PsychophysicsToolbox
# 24.184	0.002	resp	3	12092	PsychophysicsToolbox
# 24.194	0.002	resp	3	12097	PsychophysicsToolbox
# 24.204	0.002	resp	3	12102	PsychophysicsToolbox
# 24.214	0.002	resp	3	12107	PsychophysicsToolbox
# 24.224	0.002	resp	3	12112	PsychophysicsToolbox
# 24.234	0.002	resp	3	12117	PsychophysicsToolbox
# 24.244	0.002	resp	3	12122	PsychophysicsToolbox
# 24.254	0.002	resp	3	12127	PsychophysicsToolbox
# 24.264	0.002	resp	3	12132	PsychophysicsToolbox
# 24.71	0.002	stim_on	4	12355	PsychophysicsToolbox
# 25.676	0.002	resp	3	12838	PsychophysicsToolbox
# 25.694	0.002	resp	3	12847	PsychophysicsToolbox
# 25.704	0.002	resp	3	12852	PsychophysicsToolbox
# 25.714	0.002	resp	3	12857	PsychophysicsToolbox
# 25.724	0.002	resp	3	12862	PsychophysicsToolbox
# 25.734	0.002	resp	3	12867	PsychophysicsToolbox
# 25.744	0.002	resp	3	12872	PsychophysicsToolbox
# 25.754	0.002	resp	3	12877	PsychophysicsToolbox
# 25.764	0.002	resp	3	12882	PsychophysicsToolbox
# 25.774	0.002	resp	3	12887	PsychophysicsToolbox
# 25.784	0.002	resp	3	12892	PsychophysicsToolbox
# 25.794	0.002	resp	3	12897	PsychophysicsToolbox
# 25.804	0.002	resp	3	12902	PsychophysicsToolbox
# 26.096	0.002	stim_on	4	13048	PsychophysicsToolbox
# 27.104	0.002	resp	3	13552	PsychophysicsToolbox
# 27.118	0.002	resp	3	13559	PsychophysicsToolbox
# 27.128	0.002	resp	3	13564	PsychophysicsToolbox
# 27.138	0.002	resp	3	13569	PsychophysicsToolbox
# 27.148	0.002	resp	3	13574	PsychophysicsToolbox
# 27.158	0.002	resp	3	13579	PsychophysicsToolbox
# 27.168	0.002	resp	3	13584	PsychophysicsToolbox
# 27.178	0.002	resp	3	13589	PsychophysicsToolbox
# 27.188	0.002	resp	3	13594	PsychophysicsToolbox
# 27.204	0.002	resp	3	13602	PsychophysicsToolbox
# 27.214	0.002	resp	3	13607	PsychophysicsToolbox
# 27.224	0.002	resp	3	13612	PsychophysicsToolbox
# 27.234	0.002	resp	3	13617	PsychophysicsToolbox
# 27.244	0.002	resp	3	13622	PsychophysicsToolbox
# 27.798	0.002	stim_on	4	13899	PsychophysicsToolbox
# 28.674	0.002	resp	3	14337	PsychophysicsToolbox
# 28.692	0.002	resp	3	14346	PsychophysicsToolbox
# 28.702	0.002	resp	3	14351	PsychophysicsToolbox
# 28.712	0.002	resp	3	14356	PsychophysicsToolbox
# 28.722	0.002	resp	3	14361	PsychophysicsToolbox
# 28.732	0.002	resp	3	14366	PsychophysicsToolbox
# 28.742	0.002	resp	3	14371	PsychophysicsToolbox
# 28.752	0.002	resp	3	14376	PsychophysicsToolbox
# 28.762	0.002	resp	3	14381	PsychophysicsToolbox
# 28.772	0.002	resp	3	14386	PsychophysicsToolbox
# 28.782	0.002	resp	3	14391	PsychophysicsToolbox
# 28.798	0.002	resp	3	14399	PsychophysicsToolbox
# 28.808	0.002	resp	3	14404	PsychophysicsToolbox
# 29.218	0.002	stim_on	4	14609	PsychophysicsToolbox
# 30.192	0.002	resp	3	15096	PsychophysicsToolbox
# 30.21	0.002	resp	3	15105	PsychophysicsToolbox
# 30.22	0.002	resp	3	15110	PsychophysicsToolbox
# 30.23	0.002	resp	3	15115	PsychophysicsToolbox
# 30.24	0.002	resp	3	15120	PsychophysicsToolbox
# 30.25	0.002	resp	3	15125	PsychophysicsToolbox
# 30.266	0.002	resp	3	15133	PsychophysicsToolbox
# 30.276	0.002	resp	3	15138	PsychophysicsToolbox
# 30.286	0.002	resp	3	15143	PsychophysicsToolbox
# 30.296	0.002	resp	3	15148	PsychophysicsToolbox
# 30.306	0.002	resp	3	15153	PsychophysicsToolbox
# 30.904	0.002	stim_on	4	15452	PsychophysicsToolbox
# 31.818	0.002	resp	3	15909	PsychophysicsToolbox
# 31.832	0.002	resp	3	15916	PsychophysicsToolbox
# 31.842	0.002	resp	3	15921	PsychophysicsToolbox
# 31.852	0.002	resp	3	15926	PsychophysicsToolbox
# 31.862	0.002	resp	3	15931	PsychophysicsToolbox
# 31.872	0.002	resp	3	15936	PsychophysicsToolbox
# 31.882	0.002	resp	3	15941	PsychophysicsToolbox
# 31.898	0.002	resp	3	15949	PsychophysicsToolbox
# 31.908	0.002	resp	3	15954	PsychophysicsToolbox
# 31.918	0.002	resp	3	15959	PsychophysicsToolbox
# 31.928	0.002	resp	3	15964	PsychophysicsToolbox
# 31.938	0.002	resp	3	15969	PsychophysicsToolbox
# 31.948	0.002	resp	3	15974	PsychophysicsToolbox
# 31.958	0.002	resp	3	15979	PsychophysicsToolbox
# 31.968	0.002	resp	3	15984	PsychophysicsToolbox
# 31.978	0.002	resp	3	15989	PsychophysicsToolbox
# 32.306	0.002	stim_on	4	16153	PsychophysicsToolbox
# 33.274	0.002	resp	3	16637	PsychophysicsToolbox
# 33.286	0.002	resp	3	16643	PsychophysicsToolbox
# 33.296	0.002	resp	3	16648	PsychophysicsToolbox
# 33.306	0.002	resp	3	16653	PsychophysicsToolbox
# 33.322	0.002	resp	3	16661	PsychophysicsToolbox
# 33.332	0.002	resp	3	16666	PsychophysicsToolbox
# 33.342	0.002	resp	3	16671	PsychophysicsToolbox
# 33.352	0.002	resp	3	16676	PsychophysicsToolbox
# 33.362	0.002	resp	3	16681	PsychophysicsToolbox
# 33.372	0.002	resp	3	16686	PsychophysicsToolbox
# 33.382	0.002	resp	3	16691	PsychophysicsToolbox
# 33.392	0.002	resp	3	16696	PsychophysicsToolbox
# 33.402	0.002	resp	3	16701	PsychophysicsToolbox
# 33.776	0.002	stim_on	4	16888	PsychophysicsToolbox
# 34.772	0.002	resp	3	17386	PsychophysicsToolbox
# 34.786	0.002	resp	3	17393	PsychophysicsToolbox
# 34.796	0.002	resp	3	17398	PsychophysicsToolbox
# 34.806	0.002	resp	3	17403	PsychophysicsToolbox
# 34.816	0.002	resp	3	17408	PsychophysicsToolbox
# 34.826	0.002	resp	3	17413	PsychophysicsToolbox
# 34.836	0.002	resp	3	17418	PsychophysicsToolbox
# 34.846	0.002	resp	3	17423	PsychophysicsToolbox
# 34.856	0.002	resp	3	17428	PsychophysicsToolbox
# 34.866	0.002	resp	3	17433	PsychophysicsToolbox
# 34.876	0.002	resp	3	17438	PsychophysicsToolbox
# 34.886	0.002	resp	3	17443	PsychophysicsToolbox
# 34.896	0.002	resp	3	17448	PsychophysicsToolbox
# 34.906	0.002	resp	3	17453	PsychophysicsToolbox
# 35.128	0.002	stim_on	4	17564	PsychophysicsToolbox
# 36.092	0.002	resp	3	18046	PsychophysicsToolbox
# 36.106	0.002	resp	3	18053	PsychophysicsToolbox
# 36.116	0.002	resp	3	18058	PsychophysicsToolbox
# 36.126	0.002	resp	3	18063	PsychophysicsToolbox
# 36.136	0.002	resp	3	18068	PsychophysicsToolbox
# 36.146	0.002	resp	3	18073	PsychophysicsToolbox
# 36.156	0.002	resp	3	18078	PsychophysicsToolbox
# 36.166	0.002	resp	3	18083	PsychophysicsToolbox
# 36.176	0.002	resp	3	18088	PsychophysicsToolbox
# 36.186	0.002	resp	3	18093	PsychophysicsToolbox
# 36.196	0.002	resp	3	18098	PsychophysicsToolbox
# 36.206	0.002	resp	3	18103	PsychophysicsToolbox
# 36.216	0.002	resp	3	18108	PsychophysicsToolbox
# 36.698	0.002	stim_on	4	18349	PsychophysicsToolbox
# 37.54	0.002	resp	3	18770	PsychophysicsToolbox
# 37.554	0.002	resp	3	18777	PsychophysicsToolbox
# 37.564	0.002	resp	3	18782	PsychophysicsToolbox
# 37.574	0.002	resp	3	18787	PsychophysicsToolbox
# 37.584	0.002	resp	3	18792	PsychophysicsToolbox
# 37.594	0.002	resp	3	18797	PsychophysicsToolbox
# 37.604	0.002	resp	3	18802	PsychophysicsToolbox
# 37.614	0.002	resp	3	18807	PsychophysicsToolbox
# 37.63	0.002	resp	3	18815	PsychophysicsToolbox
# 37.64	0.002	resp	3	18820	PsychophysicsToolbox
# 37.65	0.002	resp	3	18825	PsychophysicsToolbox
# 37.66	0.002	resp	3	18830	PsychophysicsToolbox
# 37.67	0.002	resp	3	18835	PsychophysicsToolbox
# 37.68	0.002	resp	3	18840	PsychophysicsToolbox
# 37.69	0.002	resp	3	18845	PsychophysicsToolbox
# 38.084	0.002	stim_on	4	19042	PsychophysicsToolbox
# 39.066	0.002	resp	3	19533	PsychophysicsToolbox
# 39.078	0.002	resp	3	19539	PsychophysicsToolbox
# 39.094	0.002	resp	3	19547	PsychophysicsToolbox
# 39.104	0.002	resp	3	19552	PsychophysicsToolbox
# 39.114	0.002	resp	3	19557	PsychophysicsToolbox
# 39.124	0.002	resp	3	19562	PsychophysicsToolbox
# 39.134	0.002	resp	3	19567	PsychophysicsToolbox
# 39.144	0.002	resp	3	19572	PsychophysicsToolbox
# 39.154	0.002	resp	3	19577	PsychophysicsToolbox
# 39.164	0.002	resp	3	19582	PsychophysicsToolbox
# 39.174	0.002	resp	3	19587	PsychophysicsToolbox
# 39.184	0.002	resp	3	19592	PsychophysicsToolbox
# 39.42	0.002	stim_on	4	19710	PsychophysicsToolbox
# 40.38	0.002	resp	3	20190	PsychophysicsToolbox
# 40.404	0.002	resp	3	20202	PsychophysicsToolbox
# 40.414	0.002	resp	3	20207	PsychophysicsToolbox
# 40.424	0.002	resp	3	20212	PsychophysicsToolbox
# 40.434	0.002	resp	3	20217	PsychophysicsToolbox
# 40.444	0.002	resp	3	20222	PsychophysicsToolbox
# 40.454	0.002	resp	3	20227	PsychophysicsToolbox
# 40.464	0.002	resp	3	20232	PsychophysicsToolbox
# 40.474	0.002	resp	3	20237	PsychophysicsToolbox
# 40.484	0.002	resp	3	20242	PsychophysicsToolbox
# 40.494	0.002	resp	3	20247	PsychophysicsToolbox
# 40.504	0.002	resp	3	20252	PsychophysicsToolbox
# 40.514	0.002	resp	3	20257	PsychophysicsToolbox
# 41.022	0.002	stim_on	4	20511	PsychophysicsToolbox
# 41.97	0.002	resp	3	20985	PsychophysicsToolbox
# 41.984	0.002	resp	3	20992	PsychophysicsToolbox
# 41.994	0.002	resp	3	20997	PsychophysicsToolbox
# 42.004	0.002	resp	3	21002	PsychophysicsToolbox
# 42.014	0.002	resp	3	21007	PsychophysicsToolbox
# 42.024	0.002	resp	3	21012	PsychophysicsToolbox
# 42.034	0.002	resp	3	21017	PsychophysicsToolbox
# 42.044	0.002	resp	3	21022	PsychophysicsToolbox
# 42.054	0.002	resp	3	21027	PsychophysicsToolbox
# 42.064	0.002	resp	3	21032	PsychophysicsToolbox
# 42.08	0.002	resp	3	21040	PsychophysicsToolbox
# 42.09	0.002	resp	3	21045	PsychophysicsToolbox
# 42.1	0.002	resp	3	21050	PsychophysicsToolbox
# 42.476	0.002	stim_on	4	21238	PsychophysicsToolbox
# 43.436	0.002	resp	3	21718	PsychophysicsToolbox
# 43.454	0.002	resp	3	21727	PsychophysicsToolbox
# 43.464	0.002	resp	3	21732	PsychophysicsToolbox
# 43.474	0.002	resp	3	21737	PsychophysicsToolbox
# 43.484	0.002	resp	3	21742	PsychophysicsToolbox
# 43.494	0.002	resp	3	21747	PsychophysicsToolbox
# 43.504	0.002	resp	3	21752	PsychophysicsToolbox
# 43.514	0.002	resp	3	21757	PsychophysicsToolbox
# 43.524	0.002	resp	3	21762	PsychophysicsToolbox
# 43.534	0.002	resp	3	21767	PsychophysicsToolbox
# 43.55	0.002	resp	3	21775	PsychophysicsToolbox
# 43.56	0.002	resp	3	21780	PsychophysicsToolbox
# 43.57	0.002	resp	3	21785	PsychophysicsToolbox
# 43.58	0.002	resp	3	21790	PsychophysicsToolbox
# 43.59	0.002	resp	3	21795	PsychophysicsToolbox
# 44.046	0.002	stim_on	4	22023	PsychophysicsToolbox
# 45.014	0.002	resp	3	22507	PsychophysicsToolbox
# 45.026	0.002	resp	3	22513	PsychophysicsToolbox
# 45.036	0.002	resp	3	22518	PsychophysicsToolbox
# 45.046	0.002	resp	3	22523	PsychophysicsToolbox
# 45.056	0.002	resp	3	22528	PsychophysicsToolbox
# 45.066	0.002	resp	3	22533	PsychophysicsToolbox
# 45.082	0.002	resp	3	22541	PsychophysicsToolbox
# 45.092	0.002	resp	3	22546	PsychophysicsToolbox
# 45.102	0.002	resp	3	22551	PsychophysicsToolbox
# 45.112	0.002	resp	3	22556	PsychophysicsToolbox
# 45.122	0.002	resp	3	22561	PsychophysicsToolbox
# 45.132	0.002	resp	3	22566	PsychophysicsToolbox
# 45.514	0.002	stim_on	4	22757	PsychophysicsToolbox
# 46.47	0.002	resp	3	23235	PsychophysicsToolbox
# 46.488	0.002	resp	3	23244	PsychophysicsToolbox
# 46.498	0.002	resp	3	23249	PsychophysicsToolbox
# 46.514	0.002	resp	3	23257	PsychophysicsToolbox
# 46.524	0.002	resp	3	23262	PsychophysicsToolbox
# 46.534	0.002	resp	3	23267	PsychophysicsToolbox
# 46.544	0.002	resp	3	23272	PsychophysicsToolbox
# 46.554	0.002	resp	3	23277	PsychophysicsToolbox
# 46.564	0.002	resp	3	23282	PsychophysicsToolbox
# 46.574	0.002	resp	3	23287	PsychophysicsToolbox
# 46.584	0.002	resp	3	23292	PsychophysicsToolbox
# 46.594	0.002	resp	3	23297	PsychophysicsToolbox
# 46.604	0.002	resp	3	23302	PsychophysicsToolbox
# 47.084	0.002	stim_on	4	23542	PsychophysicsToolbox
# 48.032	0.002	resp	3	24016	PsychophysicsToolbox
# 48.046	0.002	resp	3	24023	PsychophysicsToolbox
# 48.056	0.002	resp	3	24028	PsychophysicsToolbox
# 48.066	0.002	resp	3	24033	PsychophysicsToolbox
# 48.076	0.002	resp	3	24038	PsychophysicsToolbox
# 48.092	0.002	resp	3	24046	PsychophysicsToolbox
# 48.102	0.002	resp	3	24051	PsychophysicsToolbox
# 48.112	0.002	resp	3	24056	PsychophysicsToolbox
# 48.122	0.002	resp	3	24061	PsychophysicsToolbox
# 48.132	0.002	resp	3	24066	PsychophysicsToolbox
# 48.142	0.002	resp	3	24071	PsychophysicsToolbox
# 48.152	0.002	resp	3	24076	PsychophysicsToolbox
# 48.162	0.002	resp	3	24081	PsychophysicsToolbox
# 48.404	0.002	stim_on	4	24202	PsychophysicsToolbox
# 49.394	0.002	resp	3	24697	PsychophysicsToolbox
# 49.408	0.002	resp	3	24704	PsychophysicsToolbox
# 49.418	0.002	resp	3	24709	PsychophysicsToolbox
# 49.428	0.002	resp	3	24714	PsychophysicsToolbox
# 49.444	0.002	resp	3	24722	PsychophysicsToolbox
# 49.454	0.002	resp	3	24727	PsychophysicsToolbox
# 49.464	0.002	resp	3	24732	PsychophysicsToolbox
# 49.474	0.002	resp	3	24737	PsychophysicsToolbox
# 49.484	0.002	resp	3	24742	PsychophysicsToolbox
# 49.494	0.002	resp	3	24747	PsychophysicsToolbox
# 49.504	0.002	resp	3	24752	PsychophysicsToolbox
# 49.514	0.002	resp	3	24757	PsychophysicsToolbox
# 49.524	0.002	resp	3	24762	PsychophysicsToolbox
# 49.534	0.002	resp	3	24767	PsychophysicsToolbox
# 50.09	0.002	stim_on	4	25045	PsychophysicsToolbox
# 51.066	0.002	resp	3	25533	PsychophysicsToolbox
# 51.08	0.002	resp	3	25540	PsychophysicsToolbox
# 51.09	0.002	resp	3	25545	PsychophysicsToolbox
# 51.1	0.002	resp	3	25550	PsychophysicsToolbox
# 51.11	0.002	resp	3	25555	PsychophysicsToolbox
# 51.12	0.002	resp	3	25560	PsychophysicsToolbox
# 51.13	0.002	resp	3	25565	PsychophysicsToolbox
# 51.146	0.002	resp	3	25573	PsychophysicsToolbox
# 51.156	0.002	resp	3	25578	PsychophysicsToolbox
# 51.166	0.002	resp	3	25583	PsychophysicsToolbox
# 51.176	0.002	resp	3	25588	PsychophysicsToolbox
# 51.186	0.002	resp	3	25593	PsychophysicsToolbox
# 51.196	0.002	resp	3	25598	PsychophysicsToolbox
# 51.206	0.002	resp	3	25603	PsychophysicsToolbox
# 51.216	0.002	resp	3	25608	PsychophysicsToolbox
# 51.226	0.002	resp	3	25613	PsychophysicsToolbox
# 51.726	0.002	stim_on	4	25863	PsychophysicsToolbox
# 52.672	0.002	resp	3	26336	PsychophysicsToolbox
# 52.69	0.002	resp	3	26345	PsychophysicsToolbox
# 52.7	0.002	resp	3	26350	PsychophysicsToolbox
# 52.71	0.002	resp	3	26355	PsychophysicsToolbox
# 52.726	0.002	resp	3	26363	PsychophysicsToolbox
# 52.736	0.002	resp	3	26368	PsychophysicsToolbox
# 52.746	0.002	resp	3	26373	PsychophysicsToolbox
# 52.756	0.002	resp	3	26378	PsychophysicsToolbox
# 52.766	0.002	resp	3	26383	PsychophysicsToolbox
# 52.776	0.002	resp	3	26388	PsychophysicsToolbox
# 52.786	0.002	resp	3	26393	PsychophysicsToolbox
# 52.796	0.002	resp	3	26398	PsychophysicsToolbox
# 52.806	0.002	resp	3	26403	PsychophysicsToolbox
# 52.816	0.002	resp	3	26408	PsychophysicsToolbox
# 52.826	0.002	resp	3	26413	PsychophysicsToolbox
# 52.836	0.002	resp	3	26418	PsychophysicsToolbox
# 53.346	0.002	stim_on	4	26673	PsychophysicsToolbox
# 54.322	0.002	resp	3	27161	PsychophysicsToolbox
# 54.34	0.002	resp	3	27170	PsychophysicsToolbox
# 54.35	0.002	resp	3	27175	PsychophysicsToolbox
# 54.36	0.002	resp	3	27180	PsychophysicsToolbox
# 54.376	0.002	resp	3	27188	PsychophysicsToolbox
# 54.386	0.002	resp	3	27193	PsychophysicsToolbox
# 54.396	0.002	resp	3	27198	PsychophysicsToolbox
# 54.406	0.002	resp	3	27203	PsychophysicsToolbox
# 54.416	0.002	resp	3	27208	PsychophysicsToolbox
# 54.426	0.002	resp	3	27213	PsychophysicsToolbox
# 54.982	0.002	stim_on	4	27491	PsychophysicsToolbox
# 55.852	0.002	resp	3	27926	PsychophysicsToolbox
# 55.864	0.002	resp	3	27932	PsychophysicsToolbox
# 55.874	0.002	resp	3	27937	PsychophysicsToolbox
# 55.884	0.002	resp	3	27942	PsychophysicsToolbox
# 55.894	0.002	resp	3	27947	PsychophysicsToolbox
# 55.904	0.002	resp	3	27952	PsychophysicsToolbox
# 55.92	0.002	resp	3	27960	PsychophysicsToolbox
# 55.93	0.002	resp	3	27965	PsychophysicsToolbox
# 55.94	0.002	resp	3	27970	PsychophysicsToolbox
# 55.95	0.002	resp	3	27975	PsychophysicsToolbox
# 55.96	0.002	resp	3	27980	PsychophysicsToolbox
# 55.97	0.002	resp	3	27985	PsychophysicsToolbox
# 55.98	0.002	resp	3	27990	PsychophysicsToolbox
# 55.99	0.002	resp	3	27995	PsychophysicsToolbox
# 56.0	0.002	resp	3	28000	PsychophysicsToolbox
# 56.01	0.002	resp	3	28005	PsychophysicsToolbox
# 56.452	0.002	stim_on	4	28226	PsychophysicsToolbox
# 57.396	0.002	resp	3	28698	PsychophysicsToolbox
# 57.408	0.002	resp	3	28704	PsychophysicsToolbox
# 57.418	0.002	resp	3	28709	PsychophysicsToolbox
# 57.428	0.002	resp	3	28714	PsychophysicsToolbox
# 57.438	0.002	resp	3	28719	PsychophysicsToolbox
# 57.448	0.002	resp	3	28724	PsychophysicsToolbox
# 57.458	0.002	resp	3	28729	PsychophysicsToolbox
# 57.468	0.002	resp	3	28734	PsychophysicsToolbox
# 57.478	0.002	resp	3	28739	PsychophysicsToolbox
# 57.494	0.002	resp	3	28747	PsychophysicsToolbox
# 57.504	0.002	resp	3	28752	PsychophysicsToolbox
# 57.514	0.002	resp	3	28757	PsychophysicsToolbox
# 57.524	0.002	resp	3	28762	PsychophysicsToolbox
# 57.534	0.002	resp	3	28767	PsychophysicsToolbox
# 57.544	0.002	resp	3	28772	PsychophysicsToolbox
# 58.004	0.002	stim_on	4	29002	PsychophysicsToolbox
# 58.98	0.002	resp	3	29490	PsychophysicsToolbox
# 58.994	0.002	resp	3	29497	PsychophysicsToolbox
# 59.004	0.002	resp	3	29502	PsychophysicsToolbox
# 59.014	0.002	resp	3	29507	PsychophysicsToolbox
# 59.024	0.002	resp	3	29512	PsychophysicsToolbox
# 59.034	0.002	resp	3	29517	PsychophysicsToolbox
# 59.044	0.002	resp	3	29522	PsychophysicsToolbox
# 59.054	0.002	resp	3	29527	PsychophysicsToolbox
# 59.064	0.002	resp	3	29532	PsychophysicsToolbox
# 59.074	0.002	resp	3	29537	PsychophysicsToolbox
# 59.084	0.002	resp	3	29542	PsychophysicsToolbox
# 59.094	0.002	resp	3	29547	PsychophysicsToolbox
# 59.104	0.002	resp	3	29552	PsychophysicsToolbox
# 59.54	0.002	stim_on	4	29770	PsychophysicsToolbox
# 60.498	0.002	resp	3	30249	PsychophysicsToolbox
# 60.512	0.002	resp	3	30256	PsychophysicsToolbox
# 60.522	0.002	resp	3	30261	PsychophysicsToolbox
# 60.532	0.002	resp	3	30266	PsychophysicsToolbox
# 60.542	0.002	resp	3	30271	PsychophysicsToolbox
# 60.552	0.002	resp	3	30276	PsychophysicsToolbox
# 60.562	0.002	resp	3	30281	PsychophysicsToolbox
# 60.572	0.002	resp	3	30286	PsychophysicsToolbox
# 60.582	0.002	resp	3	30291	PsychophysicsToolbox
# 60.592	0.002	resp	3	30296	PsychophysicsToolbox
# 60.602	0.002	resp	3	30301	PsychophysicsToolbox
# 61.06	0.002	stim_on	4	30530	PsychophysicsToolbox
# 62.028	0.002	resp	3	31014	PsychophysicsToolbox
# 62.046	0.002	resp	3	31023	PsychophysicsToolbox
# 62.056	0.002	resp	3	31028	PsychophysicsToolbox
# 62.066	0.002	resp	3	31033	PsychophysicsToolbox
# 62.076	0.002	resp	3	31038	PsychophysicsToolbox
# 62.086	0.002	resp	3	31043	PsychophysicsToolbox
# 62.096	0.002	resp	3	31048	PsychophysicsToolbox
# 62.106	0.002	resp	3	31053	PsychophysicsToolbox
# 62.116	0.002	resp	3	31058	PsychophysicsToolbox
# 62.132	0.002	resp	3	31066	PsychophysicsToolbox
# 62.142	0.002	resp	3	31071	PsychophysicsToolbox
# 62.152	0.002	resp	3	31076	PsychophysicsToolbox
# 62.162	0.002	resp	3	31081	PsychophysicsToolbox
# 62.172	0.002	resp	3	31086	PsychophysicsToolbox
# 62.48	0.002	stim_on	4	31240	PsychophysicsToolbox
# 63.452	0.002	resp	3	31726	PsychophysicsToolbox
# 63.47	0.002	resp	3	31735	PsychophysicsToolbox
# 63.48	0.002	resp	3	31740	PsychophysicsToolbox
# 63.49	0.002	resp	3	31745	PsychophysicsToolbox
# 63.5	0.002	resp	3	31750	PsychophysicsToolbox
# 63.51	0.002	resp	3	31755	PsychophysicsToolbox
# 63.52	0.002	resp	3	31760	PsychophysicsToolbox
# 63.53	0.002	resp	3	31765	PsychophysicsToolbox
# 63.54	0.002	resp	3	31770	PsychophysicsToolbox
# 63.55	0.002	resp	3	31775	PsychophysicsToolbox
# 63.56	0.002	resp	3	31780	PsychophysicsToolbox
# 63.57	0.002	resp	3	31785	PsychophysicsToolbox
# 63.58	0.002	resp	3	31790	PsychophysicsToolbox
# 63.59	0.002	resp	3	31795	PsychophysicsToolbox
# 63.606	0.002	resp	3	31803	PsychophysicsToolbox
# 63.882	0.002	stim_on	4	31941	PsychophysicsToolbox
# 64.814	0.002	resp	3	32407	PsychophysicsToolbox
# 64.832	0.002	resp	3	32416	PsychophysicsToolbox
# 64.842	0.002	resp	3	32421	PsychophysicsToolbox
# 64.852	0.002	resp	3	32426	PsychophysicsToolbox
# 64.862	0.002	resp	3	32431	PsychophysicsToolbox
# 64.872	0.002	resp	3	32436	PsychophysicsToolbox
# 64.882	0.002	resp	3	32441	PsychophysicsToolbox
# 64.892	0.002	resp	3	32446	PsychophysicsToolbox
# 64.902	0.002	resp	3	32451	PsychophysicsToolbox
# 64.912	0.002	resp	3	32456	PsychophysicsToolbox
# 64.922	0.002	resp	3	32461	PsychophysicsToolbox
# 65.368	0.002	stim_on	4	32684	PsychophysicsToolbox
# 66.362	0.002	resp	3	33181	PsychophysicsToolbox
# 66.376	0.002	resp	3	33188	PsychophysicsToolbox
# 66.386	0.002	resp	3	33193	PsychophysicsToolbox
# 66.396	0.002	resp	3	33198	PsychophysicsToolbox
# 66.406	0.002	resp	3	33203	PsychophysicsToolbox
# 66.416	0.002	resp	3	33208	PsychophysicsToolbox
# 66.426	0.002	resp	3	33213	PsychophysicsToolbox
# 66.436	0.002	resp	3	33218	PsychophysicsToolbox
# 66.446	0.002	resp	3	33223	PsychophysicsToolbox
# 66.456	0.002	resp	3	33228	PsychophysicsToolbox
# 66.466	0.002	resp	3	33233	PsychophysicsToolbox
# 66.476	0.002	resp	3	33238	PsychophysicsToolbox
# 66.486	0.002	resp	3	33243	PsychophysicsToolbox
# 66.496	0.002	resp	3	33248	PsychophysicsToolbox
# 66.77	0.002	stim_on	4	33385	PsychophysicsToolbox
# 67.856	0.002	resp	3	33928	PsychophysicsToolbox
# 67.874	0.002	resp	3	33937	PsychophysicsToolbox
# 67.884	0.002	resp	3	33942	PsychophysicsToolbox
# 67.894	0.002	resp	3	33947	PsychophysicsToolbox
# 67.904	0.002	resp	3	33952	PsychophysicsToolbox
# 67.92	0.002	resp	3	33960	PsychophysicsToolbox
# 67.93	0.002	resp	3	33965	PsychophysicsToolbox
# 67.94	0.002	resp	3	33970	PsychophysicsToolbox
# 67.95	0.002	resp	3	33975	PsychophysicsToolbox
# 67.96	0.002	resp	3	33980	PsychophysicsToolbox
# 68.408	0.002	stim_on	4	34204	PsychophysicsToolbox
# 69.408	0.002	resp	3	34704	PsychophysicsToolbox
# 69.42	0.002	resp	3	34710	PsychophysicsToolbox
# 69.43	0.002	resp	3	34715	PsychophysicsToolbox
# 69.44	0.002	resp	3	34720	PsychophysicsToolbox
# 69.45	0.002	resp	3	34725	PsychophysicsToolbox
# 69.466	0.002	resp	3	34733	PsychophysicsToolbox
# 69.476	0.002	resp	3	34738	PsychophysicsToolbox
# 69.486	0.002	resp	3	34743	PsychophysicsToolbox
# 69.496	0.002	resp	3	34748	PsychophysicsToolbox
# 69.506	0.002	resp	3	34753	PsychophysicsToolbox
# 69.516	0.002	resp	3	34758	PsychophysicsToolbox
# 69.526	0.002	resp	3	34763	PsychophysicsToolbox
# 69.536	0.002	resp	3	34768	PsychophysicsToolbox
# 69.546	0.002	resp	3	34773	PsychophysicsToolbox
# 69.556	0.002	resp	3	34778	PsychophysicsToolbox
# 70.11	0.002	stim_on	4	35055	PsychophysicsToolbox
# 71.098	0.002	resp	3	35549	PsychophysicsToolbox
# 71.112	0.002	resp	3	35556	PsychophysicsToolbox
# 71.122	0.002	resp	3	35561	PsychophysicsToolbox
# 71.132	0.002	resp	3	35566	PsychophysicsToolbox
# 71.142	0.002	resp	3	35571	PsychophysicsToolbox
# 71.152	0.002	resp	3	35576	PsychophysicsToolbox
# 71.162	0.002	resp	3	35581	PsychophysicsToolbox
# 71.178	0.002	resp	3	35589	PsychophysicsToolbox
# 71.188	0.002	resp	3	35594	PsychophysicsToolbox
# 71.198	0.002	resp	3	35599	PsychophysicsToolbox
# 71.208	0.002	resp	3	35604	PsychophysicsToolbox
# 71.218	0.002	resp	3	35609	PsychophysicsToolbox
# 71.228	0.002	resp	3	35614	PsychophysicsToolbox
# 71.43	0.002	stim_on	4	35715	PsychophysicsToolbox
# 72.36	0.002	resp	3	36180	PsychophysicsToolbox
# 72.374	0.002	resp	3	36187	PsychophysicsToolbox
# 72.384	0.002	resp	3	36192	PsychophysicsToolbox
# 72.39	0.002	resp	3	36195	PsychophysicsToolbox
# 72.404	0.002	resp	3	36202	PsychophysicsToolbox
# 72.414	0.002	resp	3	36207	PsychophysicsToolbox
# 72.424	0.002	resp	3	36212	PsychophysicsToolbox
# 72.434	0.002	resp	3	36217	PsychophysicsToolbox
# 72.444	0.002	resp	3	36222	PsychophysicsToolbox
# 72.454	0.002	resp	3	36227	PsychophysicsToolbox
# 72.464	0.002	resp	3	36232	PsychophysicsToolbox
# 72.474	0.002	resp	3	36237	PsychophysicsToolbox
# 72.49	0.002	resp	3	36245	PsychophysicsToolbox
# 72.948	0.002	stim_on	4	36474	PsychophysicsToolbox
# 73.926	0.002	resp	3	36963	PsychophysicsToolbox
# 73.944	0.002	resp	3	36972	PsychophysicsToolbox
# 73.954	0.002	resp	3	36977	PsychophysicsToolbox
# 73.964	0.002	resp	3	36982	PsychophysicsToolbox
# 73.974	0.002	resp	3	36987	PsychophysicsToolbox
# 73.99	0.002	resp	3	36995	PsychophysicsToolbox
# 74.0	0.002	resp	3	37000	PsychophysicsToolbox
# 74.01	0.002	resp	3	37005	PsychophysicsToolbox
# 74.02	0.002	resp	3	37010	PsychophysicsToolbox
# 74.03	0.002	resp	3	37015	PsychophysicsToolbox
# 74.04	0.002	resp	3	37020	PsychophysicsToolbox
# 74.05	0.002	resp	3	37025	PsychophysicsToolbox
# 74.06	0.002	resp	3	37030	PsychophysicsToolbox
# 74.07	0.002	resp	3	37035	PsychophysicsToolbox
# 74.08	0.002	resp	3	37040	PsychophysicsToolbox
# 74.302	0.002	stim_on	4	37151	PsychophysicsToolbox
# 75.278	0.002	resp	3	37639	PsychophysicsToolbox
# 75.296	0.002	resp	3	37648	PsychophysicsToolbox
# 75.306	0.002	resp	3	37653	PsychophysicsToolbox
# 75.316	0.002	resp	3	37658	PsychophysicsToolbox
# 75.326	0.002	resp	3	37663	PsychophysicsToolbox
# 75.336	0.002	resp	3	37668	PsychophysicsToolbox
# 75.346	0.002	resp	3	37673	PsychophysicsToolbox
# 75.356	0.002	resp	3	37678	PsychophysicsToolbox
# 75.366	0.002	resp	3	37683	PsychophysicsToolbox
# 75.376	0.002	resp	3	37688	PsychophysicsToolbox
# 75.386	0.002	resp	3	37693	PsychophysicsToolbox
# 75.396	0.002	resp	3	37698	PsychophysicsToolbox
# 75.406	0.002	resp	3	37703	PsychophysicsToolbox
# 75.416	0.002	resp	3	37708	PsychophysicsToolbox
# 75.938	0.002	stim_on	4	37969	PsychophysicsToolbox
# 76.978	0.002	resp	3	38489	PsychophysicsToolbox
# 76.996	0.002	resp	3	38498	PsychophysicsToolbox
# 77.006	0.002	resp	3	38503	PsychophysicsToolbox
# 77.016	0.002	resp	3	38508	PsychophysicsToolbox
# 77.026	0.002	resp	3	38513	PsychophysicsToolbox
# 77.036	0.002	resp	3	38518	PsychophysicsToolbox
# 77.046	0.002	resp	3	38523	PsychophysicsToolbox
# 77.056	0.002	resp	3	38528	PsychophysicsToolbox
# 77.066	0.002	resp	3	38533	PsychophysicsToolbox
# 77.076	0.002	resp	3	38538	PsychophysicsToolbox
# 77.64	0.002	stim_on	4	38820	PsychophysicsToolbox
# 78.602	0.002	resp	3	39301	PsychophysicsToolbox
# 78.614	0.002	resp	3	39307	PsychophysicsToolbox
# 78.624	0.002	resp	3	39312	PsychophysicsToolbox
# 78.634	0.002	resp	3	39317	PsychophysicsToolbox
# 78.65	0.002	resp	3	39325	PsychophysicsToolbox
# 78.66	0.002	resp	3	39330	PsychophysicsToolbox
# 78.67	0.002	resp	3	39335	PsychophysicsToolbox
# 78.68	0.002	resp	3	39340	PsychophysicsToolbox
# 78.69	0.002	resp	3	39345	PsychophysicsToolbox
# 78.7	0.002	resp	3	39350	PsychophysicsToolbox
# 78.71	0.002	resp	3	39355	PsychophysicsToolbox
# 78.72	0.002	resp	3	39360	PsychophysicsToolbox
# 78.73	0.002	resp	3	39365	PsychophysicsToolbox
# 78.74	0.002	resp	3	39370	PsychophysicsToolbox
# 78.75	0.002	resp	3	39375	PsychophysicsToolbox
# 78.976	0.002	stim_on	4	39488	PsychophysicsToolbox
# 79.944	0.002	resp	3	39972	PsychophysicsToolbox
# 79.962	0.002	resp	3	39981	PsychophysicsToolbox
# 79.972	0.002	resp	3	39986	PsychophysicsToolbox
# 79.982	0.002	resp	3	39991	PsychophysicsToolbox
# 79.998	0.002	resp	3	39999	PsychophysicsToolbox
# 80.008	0.002	resp	3	40004	PsychophysicsToolbox
# 80.018	0.002	resp	3	40009	PsychophysicsToolbox
# 80.028	0.002	resp	3	40014	PsychophysicsToolbox
# 80.038	0.002	resp	3	40019	PsychophysicsToolbox
# 80.048	0.002	resp	3	40024	PsychophysicsToolbox
# 80.058	0.002	resp	3	40029	PsychophysicsToolbox
# 80.068	0.002	resp	3	40034	PsychophysicsToolbox
# 80.078	0.002	resp	3	40039	PsychophysicsToolbox
# 80.664	0.002	stim_on	4	40332	PsychophysicsToolbox
# 81.546	0.002	resp	3	40773	PsychophysicsToolbox
# 81.564	0.002	resp	3	40782	PsychophysicsToolbox
# 81.574	0.002	resp	3	40787	PsychophysicsToolbox
# 81.59	0.002	resp	3	40795	PsychophysicsToolbox
# 81.6	0.002	resp	3	40800	PsychophysicsToolbox
# 81.61	0.002	resp	3	40805	PsychophysicsToolbox
# 81.62	0.002	resp	3	40810	PsychophysicsToolbox
# 81.63	0.002	resp	3	40815	PsychophysicsToolbox
# 81.64	0.002	resp	3	40820	PsychophysicsToolbox
# 81.65	0.002	resp	3	40825	PsychophysicsToolbox
# 81.66	0.002	resp	3	40830	PsychophysicsToolbox
# 81.67	0.002	resp	3	40835	PsychophysicsToolbox
# 81.68	0.002	resp	3	40840	PsychophysicsToolbox
# 81.69	0.002	resp	3	40845	PsychophysicsToolbox
# 81.982	0.002	stim_on	4	40991	PsychophysicsToolbox
# 82.914	0.002	resp	3	41457	PsychophysicsToolbox
# 82.932	0.002	resp	3	41466	PsychophysicsToolbox
# 82.942	0.002	resp	3	41471	PsychophysicsToolbox
# 82.952	0.002	resp	3	41476	PsychophysicsToolbox
# 82.962	0.002	resp	3	41481	PsychophysicsToolbox
# 82.978	0.002	resp	3	41489	PsychophysicsToolbox
# 82.988	0.002	resp	3	41494	PsychophysicsToolbox
# 82.998	0.002	resp	3	41499	PsychophysicsToolbox
# 83.008	0.002	resp	3	41504	PsychophysicsToolbox
# 83.018	0.002	resp	3	41509	PsychophysicsToolbox
# 83.028	0.002	resp	3	41514	PsychophysicsToolbox
# 83.038	0.002	resp	3	41519	PsychophysicsToolbox
# 83.568	0.002	stim_on	4	41784	PsychophysicsToolbox
# 84.468	0.002	resp	3	42234	PsychophysicsToolbox
# 84.482	0.002	resp	3	42241	PsychophysicsToolbox
# 84.492	0.002	resp	3	42246	PsychophysicsToolbox
# 84.502	0.002	resp	3	42251	PsychophysicsToolbox
# 84.512	0.002	resp	3	42256	PsychophysicsToolbox
# 84.522	0.002	resp	3	42261	PsychophysicsToolbox
# 84.532	0.002	resp	3	42266	PsychophysicsToolbox
# 84.542	0.002	resp	3	42271	PsychophysicsToolbox
# 84.552	0.002	resp	3	42276	PsychophysicsToolbox
# 84.562	0.002	resp	3	42281	PsychophysicsToolbox
# 84.572	0.002	resp	3	42286	PsychophysicsToolbox
# 84.582	0.002	resp	3	42291	PsychophysicsToolbox
# 84.592	0.002	resp	3	42296	PsychophysicsToolbox
# 84.602	0.002	resp	3	42301	PsychophysicsToolbox
# 84.618	0.002	resp	3	42309	PsychophysicsToolbox
# 84.628	0.002	resp	3	42314	PsychophysicsToolbox
# 85.188	0.002	stim_on	4	42594	PsychophysicsToolbox
# 86.324	0.002	resp	3	43162	PsychophysicsToolbox
# 86.338	0.002	resp	3	43169	PsychophysicsToolbox
# 86.348	0.002	resp	3	43174	PsychophysicsToolbox
# 86.358	0.002	resp	3	43179	PsychophysicsToolbox
# 86.368	0.002	resp	3	43184	PsychophysicsToolbox
# 86.378	0.002	resp	3	43189	PsychophysicsToolbox
# 86.388	0.002	resp	3	43194	PsychophysicsToolbox
# 86.398	0.002	resp	3	43199	PsychophysicsToolbox
# 86.408	0.002	resp	3	43204	PsychophysicsToolbox
# 86.418	0.002	resp	3	43209	PsychophysicsToolbox
# 86.428	0.002	resp	3	43214	PsychophysicsToolbox
# 86.444	0.002	resp	3	43222	PsychophysicsToolbox
# 86.708	0.002	stim_on	4	43354	PsychophysicsToolbox
# 87.534	0.002	resp	3	43767	PsychophysicsToolbox
# 87.552	0.002	resp	3	43776	PsychophysicsToolbox
# 87.562	0.002	resp	3	43781	PsychophysicsToolbox
# 87.572	0.002	resp	3	43786	PsychophysicsToolbox
# 87.582	0.002	resp	3	43791	PsychophysicsToolbox
# 87.592	0.002	resp	3	43796	PsychophysicsToolbox
# 87.602	0.002	resp	3	43801	PsychophysicsToolbox
# 87.612	0.002	resp	3	43806	PsychophysicsToolbox
# 87.622	0.002	resp	3	43811	PsychophysicsToolbox
# 87.632	0.002	resp	3	43816	PsychophysicsToolbox
# 87.642	0.002	resp	3	43821	PsychophysicsToolbox
# 87.652	0.002	resp	3	43826	PsychophysicsToolbox
# 87.662	0.002	resp	3	43831	PsychophysicsToolbox
# 87.672	0.002	resp	3	43836	PsychophysicsToolbox
# 87.682	0.002	resp	3	43841	PsychophysicsToolbox
# 87.692	0.002	resp	3	43846	PsychophysicsToolbox
# 88.378	0.002	stim_on	4	44189	PsychophysicsToolbox
# 89.38	0.002	resp	3	44690	PsychophysicsToolbox
# 89.394	0.002	resp	3	44697	PsychophysicsToolbox
# 89.404	0.002	resp	3	44702	PsychophysicsToolbox
# 89.414	0.002	resp	3	44707	PsychophysicsToolbox
# 89.43	0.002	resp	3	44715	PsychophysicsToolbox
# 89.44	0.002	resp	3	44720	PsychophysicsToolbox
# 89.45	0.002	resp	3	44725	PsychophysicsToolbox
# 89.46	0.002	resp	3	44730	PsychophysicsToolbox
# 89.47	0.002	resp	3	44735	PsychophysicsToolbox
# 89.48	0.002	resp	3	44740	PsychophysicsToolbox
# 89.49	0.002	resp	3	44745	PsychophysicsToolbox
# 90.048	0.002	stim_on	4	45024	PsychophysicsToolbox
# 91.03	0.002	resp	3	45515	PsychophysicsToolbox
# 91.048	0.002	resp	3	45524	PsychophysicsToolbox
# 91.058	0.002	resp	3	45529	PsychophysicsToolbox
# 91.068	0.002	resp	3	45534	PsychophysicsToolbox
# 91.078	0.002	resp	3	45539	PsychophysicsToolbox
# 91.094	0.002	resp	3	45547	PsychophysicsToolbox
# 91.104	0.002	resp	3	45552	PsychophysicsToolbox
# 91.114	0.002	resp	3	45557	PsychophysicsToolbox
# 91.124	0.002	resp	3	45562	PsychophysicsToolbox
# 91.134	0.002	resp	3	45567	PsychophysicsToolbox
# 91.144	0.002	resp	3	45572	PsychophysicsToolbox
# 91.154	0.002	resp	3	45577	PsychophysicsToolbox
# 91.164	0.002	resp	3	45582	PsychophysicsToolbox
# 91.616	0.002	stim_on	4	45808	PsychophysicsToolbox
# 92.604	0.002	resp	3	46302	PsychophysicsToolbox
# 92.618	0.002	resp	3	46309	PsychophysicsToolbox
# 92.628	0.002	resp	3	46314	PsychophysicsToolbox
# 92.638	0.002	resp	3	46319	PsychophysicsToolbox
# 92.648	0.002	resp	3	46324	PsychophysicsToolbox
# 92.658	0.002	resp	3	46329	PsychophysicsToolbox
# 92.668	0.002	resp	3	46334	PsychophysicsToolbox
# 92.678	0.002	resp	3	46339	PsychophysicsToolbox
# 92.688	0.002	resp	3	46344	PsychophysicsToolbox
# 92.698	0.002	resp	3	46349	PsychophysicsToolbox
# 92.708	0.002	resp	3	46354	PsychophysicsToolbox
# 92.718	0.002	resp	3	46359	PsychophysicsToolbox
# 92.986	0.002	stim_on	4	46493	PsychophysicsToolbox
# 93.974	0.002	resp	3	46987	PsychophysicsToolbox
# 93.988	0.002	resp	3	46994	PsychophysicsToolbox
# 93.998	0.002	resp	3	46999	PsychophysicsToolbox
# 94.008	0.002	resp	3	47004	PsychophysicsToolbox
# 94.018	0.002	resp	3	47009	PsychophysicsToolbox
# 94.028	0.002	resp	3	47014	PsychophysicsToolbox
# 94.038	0.002	resp	3	47019	PsychophysicsToolbox
# 94.048	0.002	resp	3	47024	PsychophysicsToolbox
# 94.058	0.002	resp	3	47029	PsychophysicsToolbox
# 94.074	0.002	resp	3	47037	PsychophysicsToolbox
# 94.084	0.002	resp	3	47042	PsychophysicsToolbox
# 94.094	0.002	resp	3	47047	PsychophysicsToolbox
# 94.104	0.002	resp	3	47052	PsychophysicsToolbox
# 94.114	0.002	resp	3	47057	PsychophysicsToolbox
# 94.124	0.002	resp	3	47062	PsychophysicsToolbox
# 94.134	0.002	resp	3	47067	PsychophysicsToolbox
# 94.144	0.002	resp	3	47072	PsychophysicsToolbox
# 94.388	0.002	stim_on	4	47194	PsychophysicsToolbox
# 95.314	0.002	resp	3	47657	PsychophysicsToolbox
# 95.328	0.002	resp	3	47664	PsychophysicsToolbox
# 95.338	0.002	resp	3	47669	PsychophysicsToolbox
# 95.348	0.002	resp	3	47674	PsychophysicsToolbox
# 95.358	0.002	resp	3	47679	PsychophysicsToolbox
# 95.374	0.002	resp	3	47687	PsychophysicsToolbox
# 95.384	0.002	resp	3	47692	PsychophysicsToolbox
# 95.394	0.002	resp	3	47697	PsychophysicsToolbox
# 95.404	0.002	resp	3	47702	PsychophysicsToolbox
# 95.414	0.002	resp	3	47707	PsychophysicsToolbox
# 95.424	0.002	resp	3	47712	PsychophysicsToolbox
# 95.434	0.002	resp	3	47717	PsychophysicsToolbox
# 95.774	0.002	stim_on	4	47887	PsychophysicsToolbox
# 96.73	0.002	resp	3	48365	PsychophysicsToolbox
# 96.748	0.002	resp	3	48374	PsychophysicsToolbox
# 96.758	0.002	resp	3	48379	PsychophysicsToolbox
# 96.768	0.002	resp	3	48384	PsychophysicsToolbox
# 96.778	0.002	resp	3	48389	PsychophysicsToolbox
# 96.788	0.002	resp	3	48394	PsychophysicsToolbox
# 96.798	0.002	resp	3	48399	PsychophysicsToolbox
# 96.808	0.002	resp	3	48404	PsychophysicsToolbox
# 96.818	0.002	resp	3	48409	PsychophysicsToolbox
# 96.828	0.002	resp	3	48414	PsychophysicsToolbox
# 96.838	0.002	resp	3	48419	PsychophysicsToolbox
# 96.848	0.002	resp	3	48424	PsychophysicsToolbox
# 96.864	0.002	resp	3	48432	PsychophysicsToolbox
# 96.874	0.002	resp	3	48437	PsychophysicsToolbox
# 96.884	0.002	resp	3	48442	PsychophysicsToolbox
# 96.894	0.002	resp	3	48447	PsychophysicsToolbox
# 97.094	0.002	stim_on	4	48547	PsychophysicsToolbox
# 98.112	0.002	resp	3	49056	PsychophysicsToolbox
# 98.13	0.002	resp	3	49065	PsychophysicsToolbox
# 98.14	0.002	resp	3	49070	PsychophysicsToolbox
# 98.15	0.002	resp	3	49075	PsychophysicsToolbox
# 98.16	0.002	resp	3	49080	PsychophysicsToolbox
# 98.17	0.002	resp	3	49085	PsychophysicsToolbox
# 98.18	0.002	resp	3	49090	PsychophysicsToolbox
# 98.196	0.002	resp	3	49098	PsychophysicsToolbox
# 98.206	0.002	resp	3	49103	PsychophysicsToolbox
# 98.216	0.002	resp	3	49108	PsychophysicsToolbox
# 98.226	0.002	resp	3	49113	PsychophysicsToolbox
# 98.236	0.002	resp	3	49118	PsychophysicsToolbox
# 98.246	0.002	resp	3	49123	PsychophysicsToolbox
# 98.256	0.002	resp	3	49128	PsychophysicsToolbox
# 98.446	0.002	stim_on	4	49223	PsychophysicsToolbox
# 99.366	0.002	resp	3	49683	PsychophysicsToolbox
# 99.378	0.002	resp	3	49689	PsychophysicsToolbox
# 99.388	0.002	resp	3	49694	PsychophysicsToolbox
# 99.398	0.002	resp	3	49699	PsychophysicsToolbox
# 99.408	0.002	resp	3	49704	PsychophysicsToolbox
# 99.424	0.002	resp	3	49712	PsychophysicsToolbox
# 99.434	0.002	resp	3	49717	PsychophysicsToolbox
# 99.444	0.002	resp	3	49722	PsychophysicsToolbox
# 99.454	0.002	resp	3	49727	PsychophysicsToolbox
# 99.464	0.002	resp	3	49732	PsychophysicsToolbox
# 99.474	0.002	resp	3	49737	PsychophysicsToolbox
# 99.484	0.002	resp	3	49742	PsychophysicsToolbox
# 99.494	0.002	resp	3	49747	PsychophysicsToolbox
# 99.504	0.002	resp	3	49752	PsychophysicsToolbox
# 99.998	0.002	stim_on	4	49999	PsychophysicsToolbox
# 100.942	0.002	resp	3	50471	PsychophysicsToolbox
# 100.96	0.002	resp	3	50480	PsychophysicsToolbox
# 100.97	0.002	resp	3	50485	PsychophysicsToolbox
# 100.986	0.002	resp	3	50493	PsychophysicsToolbox
# 100.996	0.002	resp	3	50498	PsychophysicsToolbox
# 101.006	0.002	resp	3	50503	PsychophysicsToolbox
# 101.016	0.002	resp	3	50508	PsychophysicsToolbox
# 101.026	0.002	resp	3	50513	PsychophysicsToolbox
# 101.036	0.002	resp	3	50518	PsychophysicsToolbox
# 101.046	0.002	resp	3	50523	PsychophysicsToolbox
# 101.056	0.002	resp	3	50528	PsychophysicsToolbox
# 101.686	0.002	stim_on	4	50843	PsychophysicsToolbox
# 102.318	0.002	resp	3	51159	PsychophysicsToolbox
# 102.336	0.002	resp	3	51168	PsychophysicsToolbox
# 102.346	0.002	resp	3	51173	PsychophysicsToolbox
# 102.362	0.002	resp	3	51181	PsychophysicsToolbox
# 102.372	0.002	resp	3	51186	PsychophysicsToolbox
# 103.138	0.002	stim_on	4	51569	PsychophysicsToolbox
# 103.942	0.002	resp	3	51971	PsychophysicsToolbox
# 103.956	0.002	resp	3	51978	PsychophysicsToolbox
# 103.966	0.002	resp	3	51983	PsychophysicsToolbox
# 103.976	0.002	resp	3	51988	PsychophysicsToolbox
# 103.986	0.002	resp	3	51993	PsychophysicsToolbox
# 103.996	0.002	resp	3	51998	PsychophysicsToolbox
# 104.006	0.002	resp	3	52003	PsychophysicsToolbox
# 104.016	0.002	resp	3	52008	PsychophysicsToolbox
# 104.026	0.002	resp	3	52013	PsychophysicsToolbox
# 104.036	0.002	resp	3	52018	PsychophysicsToolbox
# 104.046	0.002	resp	3	52023	PsychophysicsToolbox
# 104.056	0.002	resp	3	52028	PsychophysicsToolbox
# 104.066	0.002	resp	3	52033	PsychophysicsToolbox
# 104.076	0.002	resp	3	52038	PsychophysicsToolbox
# 104.608	0.002	stim_on	4	52304	PsychophysicsToolbox
# 105.654	0.002	resp	3	52827	PsychophysicsToolbox
# 105.672	0.002	resp	3	52836	PsychophysicsToolbox
# 105.682	0.002	resp	3	52841	PsychophysicsToolbox
# 105.692	0.002	resp	3	52846	PsychophysicsToolbox
# 105.702	0.002	resp	3	52851	PsychophysicsToolbox
# 105.712	0.002	resp	3	52856	PsychophysicsToolbox
# 105.722	0.002	resp	3	52861	PsychophysicsToolbox
# 105.732	0.002	resp	3	52866	PsychophysicsToolbox
# 105.742	0.002	resp	3	52871	PsychophysicsToolbox
# 105.752	0.002	resp	3	52876	PsychophysicsToolbox
# 105.762	0.002	resp	3	52881	PsychophysicsToolbox
# 105.772	0.002	resp	3	52886	PsychophysicsToolbox
# 105.782	0.002	resp	3	52891	PsychophysicsToolbox
# 105.792	0.002	resp	3	52896	PsychophysicsToolbox
# 106.31	0.002	stim_on	4	53155	PsychophysicsToolbox
# 107.32	0.002	resp	3	53660	PsychophysicsToolbox
# 107.338	0.002	resp	3	53669	PsychophysicsToolbox
# 107.348	0.002	resp	3	53674	PsychophysicsToolbox
# 107.358	0.002	resp	3	53679	PsychophysicsToolbox
# 107.368	0.002	resp	3	53684	PsychophysicsToolbox
# 107.378	0.002	resp	3	53689	PsychophysicsToolbox
# 107.388	0.002	resp	3	53694	PsychophysicsToolbox
# 107.398	0.002	resp	3	53699	PsychophysicsToolbox
# 107.408	0.002	resp	3	53704	PsychophysicsToolbox
# 107.418	0.002	resp	3	53709	PsychophysicsToolbox
# 107.428	0.002	resp	3	53714	PsychophysicsToolbox
# 107.438	0.002	resp	3	53719	PsychophysicsToolbox
# 107.454	0.002	resp	3	53727	PsychophysicsToolbox
# 107.464	0.002	resp	3	53732	PsychophysicsToolbox
# 107.474	0.002	resp	3	53737	PsychophysicsToolbox
# 107.996	0.002	stim_on	4	53998	PsychophysicsToolbox
# 109.006	0.002	resp	3	54503	PsychophysicsToolbox
# 109.012	0.002	resp	3	54506	PsychophysicsToolbox
# 109.022	0.002	resp	3	54511	PsychophysicsToolbox
# 109.038	0.002	resp	3	54519	PsychophysicsToolbox
# 109.048	0.002	resp	3	54524	PsychophysicsToolbox
# 109.058	0.002	resp	3	54529	PsychophysicsToolbox
# 109.068	0.002	resp	3	54534	PsychophysicsToolbox
# 109.078	0.002	resp	3	54539	PsychophysicsToolbox
# 109.088	0.002	resp	3	54544	PsychophysicsToolbox
# 109.098	0.002	resp	3	54549	PsychophysicsToolbox
# 109.108	0.002	resp	3	54554	PsychophysicsToolbox
# 109.118	0.002	resp	3	54559	PsychophysicsToolbox
# 109.128	0.002	resp	3	54564	PsychophysicsToolbox
# 109.138	0.002	resp	3	54569	PsychophysicsToolbox
# 109.584	0.002	stim_on	4	54792	PsychophysicsToolbox
# 110.586	0.002	resp	3	55293	PsychophysicsToolbox
# 110.604	0.002	resp	3	55302	PsychophysicsToolbox
# 110.614	0.002	resp	3	55307	PsychophysicsToolbox
# 110.624	0.002	resp	3	55312	PsychophysicsToolbox
# 110.634	0.002	resp	3	55317	PsychophysicsToolbox
# 110.644	0.002	resp	3	55322	PsychophysicsToolbox
# 110.654	0.002	resp	3	55327	PsychophysicsToolbox
# 110.664	0.002	resp	3	55332	PsychophysicsToolbox
# 110.674	0.002	resp	3	55337	PsychophysicsToolbox
# 110.69	0.002	resp	3	55345	PsychophysicsToolbox
# 110.7	0.002	resp	3	55350	PsychophysicsToolbox
# 110.71	0.002	resp	3	55355	PsychophysicsToolbox
# 110.72	0.002	resp	3	55360	PsychophysicsToolbox
# 110.73	0.002	resp	3	55365	PsychophysicsToolbox
# 111.286	0.002	stim_on	4	55643	PsychophysicsToolbox
# 112.244	0.002	resp	3	56122	PsychophysicsToolbox
# 112.262	0.002	resp	3	56131	PsychophysicsToolbox
# 112.272	0.002	resp	3	56136	PsychophysicsToolbox
# ...
# 151.898	0.002	resp	3	75949	PsychophysicsToolbox
# 151.908	0.002	resp	3	75954	PsychophysicsToolbox
# 151.918	0.002	resp	3	75959	PsychophysicsToolbox
# 151.928	0.002	resp	3	75964	PsychophysicsToolbox
# 151.944	0.002	resp	3	75972	PsychophysicsToolbox
# 151.954	0.002	resp	3	75977	PsychophysicsToolbox
# 151.964	0.002	resp	3	75982	PsychophysicsToolbox
# 151.974	0.002	resp	3	75987	PsychophysicsToolbox
# 151.984	0.002	resp	3	75992	PsychophysicsToolbox
# 151.994	0.002	resp	3	75997	PsychophysicsToolbox
# 152.004	0.002	resp	3	76002	PsychophysicsToolbox
# 152.412	0.002	stim_on	4	76206	PsychophysicsToolbox
# 153.55	0.002	resp	3	76775	PsychophysicsToolbox
# 153.564	0.002	resp	3	76782	PsychophysicsToolbox
# 153.574	0.002	resp	3	76787	PsychophysicsToolbox
# 153.584	0.002	resp	3	76792	PsychophysicsToolbox
# 153.6	0.002	resp	3	76800	PsychophysicsToolbox
# 153.61	0.002	resp	3	76805	PsychophysicsToolbox
# 153.62	0.002	resp	3	76810	PsychophysicsToolbox
# 153.63	0.002	resp	3	76815	PsychophysicsToolbox
# 153.64	0.002	resp	3	76820	PsychophysicsToolbox
# 153.65	0.002	resp	3	76825	PsychophysicsToolbox
# 154.032	0.002	stim_on	4	77016	PsychophysicsToolbox
# 155.006	0.002	resp	3	77503	PsychophysicsToolbox
# 155.018	0.002	resp	3	77509	PsychophysicsToolbox
# 155.028	0.002	resp	3	77514	PsychophysicsToolbox
# 155.038	0.002	resp	3	77519	PsychophysicsToolbox
# 155.048	0.002	resp	3	77524	PsychophysicsToolbox
# 155.058	0.002	resp	3	77529	PsychophysicsToolbox
# 155.068	0.002	resp	3	77534	PsychophysicsToolbox
# 155.078	0.002	resp	3	77539	PsychophysicsToolbox
# 155.088	0.002	resp	3	77544	PsychophysicsToolbox
# 155.098	0.002	resp	3	77549	PsychophysicsToolbox
# 155.108	0.002	resp	3	77554	PsychophysicsToolbox
# 155.618	0.002	stim_on	4	77809	PsychophysicsToolbox
# 156.59	0.002	resp	3	78295	PsychophysicsToolbox
# 156.608	0.002	resp	3	78304	PsychophysicsToolbox
# 156.618	0.002	resp	3	78309	PsychophysicsToolbox
# 156.628	0.002	resp	3	78314	PsychophysicsToolbox
# 156.638	0.002	resp	3	78319	PsychophysicsToolbox
# 156.648	0.002	resp	3	78324	PsychophysicsToolbox
# 156.658	0.002	resp	3	78329	PsychophysicsToolbox
# 156.668	0.002	resp	3	78334	PsychophysicsToolbox
# 156.678	0.002	resp	3	78339	PsychophysicsToolbox
# 156.688	0.002	resp	3	78344	PsychophysicsToolbox
# 156.938	0.002	stim_on	4	78469	PsychophysicsToolbox
# 158.33	0.002	resp	3	79165	PsychophysicsToolbox
# 158.344	0.002	resp	3	79172	PsychophysicsToolbox
# 158.354	0.002	resp	3	79177	PsychophysicsToolbox
# 158.364	0.002	resp	3	79182	PsychophysicsToolbox
# 158.374	0.002	resp	3	79187	PsychophysicsToolbox
# 158.39	0.002	resp	3	79195	PsychophysicsToolbox
# 158.4	0.002	resp	3	79200	PsychophysicsToolbox
# 158.41	0.002	resp	3	79205	PsychophysicsToolbox
# 158.42	0.002	resp	3	79210	PsychophysicsToolbox
# 158.43	0.002	resp	3	79215	PsychophysicsToolbox
# 158.44	0.002	resp	3	79220	PsychophysicsToolbox
# 158.45	0.002	resp	3	79225	PsychophysicsToolbox
# 158.59	0.002	stim_on	4	79295	PsychophysicsToolbox
# 159.606	0.002	resp	3	79803	PsychophysicsToolbox
# 159.62	0.002	resp	3	79810	PsychophysicsToolbox
# 159.63	0.002	resp	3	79815	PsychophysicsToolbox
# 159.64	0.002	resp	3	79820	PsychophysicsToolbox
# 159.65	0.002	resp	3	79825	PsychophysicsToolbox
# 159.66	0.002	resp	3	79830	PsychophysicsToolbox
# 159.67	0.002	resp	3	79835	PsychophysicsToolbox
# 159.68	0.002	resp	3	79840	PsychophysicsToolbox
# 159.69	0.002	resp	3	79845	PsychophysicsToolbox
# 159.7	0.002	resp	3	79850	PsychophysicsToolbox
# 159.71	0.002	resp	3	79855	PsychophysicsToolbox
# 159.72	0.002	resp	3	79860	PsychophysicsToolbox
# 159.73	0.002	resp	3	79865	PsychophysicsToolbox
# 160.278	0.002	stim_on	4	80139	PsychophysicsToolbox
# 161.516	0.002	resp	3	80758	PsychophysicsToolbox
# 161.534	0.002	resp	3	80767	PsychophysicsToolbox
# 161.544	0.002	resp	3	80772	PsychophysicsToolbox
# 161.554	0.002	resp	3	80777	PsychophysicsToolbox
# 161.564	0.002	resp	3	80782	PsychophysicsToolbox
# 161.574	0.002	resp	3	80787	PsychophysicsToolbox
# 161.584	0.002	resp	3	80792	PsychophysicsToolbox
# 161.594	0.002	resp	3	80797	PsychophysicsToolbox
# 161.604	0.002	resp	3	80802	PsychophysicsToolbox
# 161.614	0.002	resp	3	80807	PsychophysicsToolbox
# 161.624	0.002	resp	3	80812	PsychophysicsToolbox
# 161.634	0.002	resp	3	80817	PsychophysicsToolbox
# 161.644	0.002	resp	3	80822	PsychophysicsToolbox
# 161.896	0.002	stim_on	4	80948	PsychophysicsToolbox
# 162.9	0.002	resp	3	81450	PsychophysicsToolbox
# 162.918	0.002	resp	3	81459	PsychophysicsToolbox
# 162.928	0.002	resp	3	81464	PsychophysicsToolbox
# 162.938	0.002	resp	3	81469	PsychophysicsToolbox
# 162.948	0.002	resp	3	81474	PsychophysicsToolbox
# 162.958	0.002	resp	3	81479	PsychophysicsToolbox
# 162.968	0.002	resp	3	81484	PsychophysicsToolbox
# 162.978	0.002	resp	3	81489	PsychophysicsToolbox
# 162.988	0.002	resp	3	81494	PsychophysicsToolbox
# 162.998	0.002	resp	3	81499	PsychophysicsToolbox
# 163.008	0.002	resp	3	81504	PsychophysicsToolbox
# 163.024	0.002	resp	3	81512	PsychophysicsToolbox
# 163.216	0.002	stim_on	4	81608	PsychophysicsToolbox
# 164.234	0.002	resp	3	82117	PsychophysicsToolbox
# 164.252	0.002	resp	3	82126	PsychophysicsToolbox
# 164.262	0.002	resp	3	82131	PsychophysicsToolbox
# 164.272	0.002	resp	3	82136	PsychophysicsToolbox
# 164.282	0.002	resp	3	82141	PsychophysicsToolbox
# 164.292	0.002	resp	3	82146	PsychophysicsToolbox
# 164.302	0.002	resp	3	82151	PsychophysicsToolbox
# 164.318	0.002	resp	3	82159	PsychophysicsToolbox
# 164.328	0.002	resp	3	82164	PsychophysicsToolbox
# 164.338	0.002	resp	3	82169	PsychophysicsToolbox
# 164.348	0.002	resp	3	82174	PsychophysicsToolbox
# 164.358	0.002	resp	3	82179	PsychophysicsToolbox
# 164.686	0.002	stim_on	4	82343	PsychophysicsToolbox
# 165.71	0.002	resp	3	82855	PsychophysicsToolbox
# 165.724	0.002	resp	3	82862	PsychophysicsToolbox
# 165.734	0.002	resp	3	82867	PsychophysicsToolbox
# 165.744	0.002	resp	3	82872	PsychophysicsToolbox
# 165.754	0.002	resp	3	82877	PsychophysicsToolbox
# 165.764	0.002	resp	3	82882	PsychophysicsToolbox
# 165.774	0.002	resp	3	82887	PsychophysicsToolbox
# 165.784	0.002	resp	3	82892	PsychophysicsToolbox
# 165.794	0.002	resp	3	82897	PsychophysicsToolbox
# 165.804	0.002	resp	3	82902	PsychophysicsToolbox
# 165.814	0.002	resp	3	82907	PsychophysicsToolbox
# 165.824	0.002	resp	3	82912	PsychophysicsToolbox
# 165.834	0.002	resp	3	82917	PsychophysicsToolbox
# 166.288	0.002	stim_on	4	83144	PsychophysicsToolbox
# 167.288	0.002	resp	3	83644	PsychophysicsToolbox
# 167.306	0.002	resp	3	83653	PsychophysicsToolbox
# 167.316	0.002	resp	3	83658	PsychophysicsToolbox
# 167.326	0.002	resp	3	83663	PsychophysicsToolbox
# 167.336	0.002	resp	3	83668	PsychophysicsToolbox
# 167.346	0.002	resp	3	83673	PsychophysicsToolbox
# 167.356	0.002	resp	3	83678	PsychophysicsToolbox
# 167.366	0.002	resp	3	83683	PsychophysicsToolbox
# 167.376	0.002	resp	3	83688	PsychophysicsToolbox
# 167.386	0.002	resp	3	83693	PsychophysicsToolbox
# 167.396	0.002	resp	3	83698	PsychophysicsToolbox
# 167.406	0.002	resp	3	83703	PsychophysicsToolbox
# 167.892	0.002	stim_on	4	83946	PsychophysicsToolbox
# 168.884	0.002	resp	3	84442	PsychophysicsToolbox
# 168.902	0.002	resp	3	84451	PsychophysicsToolbox
# 168.912	0.002	resp	3	84456	PsychophysicsToolbox
# 168.922	0.002	resp	3	84461	PsychophysicsToolbox
# 168.932	0.002	resp	3	84466	PsychophysicsToolbox
# 168.942	0.002	resp	3	84471	PsychophysicsToolbox
# 168.952	0.002	resp	3	84476	PsychophysicsToolbox
# 168.962	0.002	resp	3	84481	PsychophysicsToolbox
# 168.972	0.002	resp	3	84486	PsychophysicsToolbox
# 168.982	0.002	resp	3	84491	PsychophysicsToolbox
# 168.998	0.002	resp	3	84499	PsychophysicsToolbox
# 169.294	0.002	stim_on	4	84647	PsychophysicsToolbox
# 170.36	0.002	resp	3	85180	PsychophysicsToolbox
# 170.378	0.002	resp	3	85189	PsychophysicsToolbox
# 170.388	0.002	resp	3	85194	PsychophysicsToolbox
# 170.398	0.002	resp	3	85199	PsychophysicsToolbox
# 170.408	0.002	resp	3	85204	PsychophysicsToolbox
# 170.418	0.002	resp	3	85209	PsychophysicsToolbox
# 170.428	0.002	resp	3	85214	PsychophysicsToolbox
# 170.444	0.002	resp	3	85222	PsychophysicsToolbox
# 170.454	0.002	resp	3	85227	PsychophysicsToolbox
# 170.464	0.002	resp	3	85232	PsychophysicsToolbox
# 170.474	0.002	resp	3	85237	PsychophysicsToolbox
# 170.714	0.002	stim_on	4	85357	PsychophysicsToolbox
# 171.71	0.002	resp	3	85855	PsychophysicsToolbox
# 171.724	0.002	resp	3	85862	PsychophysicsToolbox
# 171.734	0.002	resp	3	85867	PsychophysicsToolbox
# 171.744	0.002	resp	3	85872	PsychophysicsToolbox
# 171.754	0.002	resp	3	85877	PsychophysicsToolbox
# 171.764	0.002	resp	3	85882	PsychophysicsToolbox
# 171.774	0.002	resp	3	85887	PsychophysicsToolbox
# 171.784	0.002	resp	3	85892	PsychophysicsToolbox
# 171.8	0.002	resp	3	85900	PsychophysicsToolbox
# 171.81	0.002	resp	3	85905	PsychophysicsToolbox
# 171.82	0.002	resp	3	85910	PsychophysicsToolbox
# 172.3	0.002	stim_on	4	86150	PsychophysicsToolbox
# 173.31	0.002	resp	3	86655	PsychophysicsToolbox
# 173.328	0.002	resp	3	86664	PsychophysicsToolbox
# 173.338	0.002	resp	3	86669	PsychophysicsToolbox
# 173.348	0.002	resp	3	86674	PsychophysicsToolbox
# 173.358	0.002	resp	3	86679	PsychophysicsToolbox
# 173.368	0.002	resp	3	86684	PsychophysicsToolbox
# 173.378	0.002	resp	3	86689	PsychophysicsToolbox
# 173.388	0.002	resp	3	86694	PsychophysicsToolbox
# 173.398	0.002	resp	3	86699	PsychophysicsToolbox
# 173.408	0.002	resp	3	86704	PsychophysicsToolbox
# 173.418	0.002	resp	3	86709	PsychophysicsToolbox
# 173.434	0.002	resp	3	86717	PsychophysicsToolbox
# 173.444	0.002	resp	3	86722	PsychophysicsToolbox
# 173.454	0.002	resp	3	86727	PsychophysicsToolbox
# 173.464	0.002	resp	3	86732	PsychophysicsToolbox
# 173.802	0.002	stim_on	4	86901	PsychophysicsToolbox
# 174.75	0.002	resp	3	87375	PsychophysicsToolbox
# 174.768	0.002	resp	3	87384	PsychophysicsToolbox
# 174.778	0.002	resp	3	87389	PsychophysicsToolbox
# 174.794	0.002	resp	3	87397	PsychophysicsToolbox
# 174.804	0.002	resp	3	87402	PsychophysicsToolbox
# 174.814	0.002	resp	3	87407	PsychophysicsToolbox
# 174.824	0.002	resp	3	87412	PsychophysicsToolbox
# 174.834	0.002	resp	3	87417	PsychophysicsToolbox
# 174.844	0.002	resp	3	87422	PsychophysicsToolbox
# 174.854	0.002	resp	3	87427	PsychophysicsToolbox
# 174.864	0.002	resp	3	87432	PsychophysicsToolbox
# 174.874	0.002	resp	3	87437	PsychophysicsToolbox
# 174.884	0.002	resp	3	87442	PsychophysicsToolbox
# 175.372	0.002	stim_on	4	87686	PsychophysicsToolbox
# 176.366	0.002	resp	3	88183	PsychophysicsToolbox
# 176.384	0.002	resp	3	88192	PsychophysicsToolbox
# 176.394	0.002	resp	3	88197	PsychophysicsToolbox
# 176.404	0.002	resp	3	88202	PsychophysicsToolbox
# 176.414	0.002	resp	3	88207	PsychophysicsToolbox
# 176.424	0.002	resp	3	88212	PsychophysicsToolbox
# 176.434	0.002	resp	3	88217	PsychophysicsToolbox
# 176.444	0.002	resp	3	88222	PsychophysicsToolbox
# 176.46	0.002	resp	3	88230	PsychophysicsToolbox
# 176.47	0.002	resp	3	88235	PsychophysicsToolbox
# 176.48	0.002	resp	3	88240	PsychophysicsToolbox
# 176.774	0.002	stim_on	4	88387	PsychophysicsToolbox
# 177.766	0.002	resp	3	88883	PsychophysicsToolbox
# 177.78	0.002	resp	3	88890	PsychophysicsToolbox
# 177.79	0.002	resp	3	88895	PsychophysicsToolbox
# 177.806	0.002	resp	3	88903	PsychophysicsToolbox
# 177.816	0.002	resp	3	88908	PsychophysicsToolbox
# 177.826	0.002	resp	3	88913	PsychophysicsToolbox
# 177.836	0.002	resp	3	88918	PsychophysicsToolbox
# 177.846	0.002	resp	3	88923	PsychophysicsToolbox
# 177.856	0.002	resp	3	88928	PsychophysicsToolbox
# 177.866	0.002	resp	3	88933	PsychophysicsToolbox
# 177.876	0.002	resp	3	88938	PsychophysicsToolbox
# 178.16	0.002	stim_on	4	89080	PsychophysicsToolbox
# 179.162	0.002	resp	3	89581	PsychophysicsToolbox
# 179.176	0.002	resp	3	89588	PsychophysicsToolbox
# 179.186	0.002	resp	3	89593	PsychophysicsToolbox
# 179.196	0.002	resp	3	89598	PsychophysicsToolbox
# 179.206	0.002	resp	3	89603	PsychophysicsToolbox
# 179.216	0.002	resp	3	89608	PsychophysicsToolbox
# 179.226	0.002	resp	3	89613	PsychophysicsToolbox
# 179.236	0.002	resp	3	89618	PsychophysicsToolbox
# 179.246	0.002	resp	3	89623	PsychophysicsToolbox
# 179.256	0.002	resp	3	89628	PsychophysicsToolbox
# 179.266	0.002	resp	3	89633	PsychophysicsToolbox
# 179.276	0.002	resp	3	89638	PsychophysicsToolbox
# 179.286	0.002	resp	3	89643	PsychophysicsToolbox
# 179.296	0.002	resp	3	89648	PsychophysicsToolbox
# 179.814	0.002	stim_on	4	89907	PsychophysicsToolbox
# 180.812	0.002	resp	3	90406	PsychophysicsToolbox
# 180.83	0.002	resp	3	90415	PsychophysicsToolbox
# 180.84	0.002	resp	3	90420	PsychophysicsToolbox
# 180.85	0.002	resp	3	90425	PsychophysicsToolbox
# 180.86	0.002	resp	3	90430	PsychophysicsToolbox
# 180.87	0.002	resp	3	90435	PsychophysicsToolbox
# 180.886	0.002	resp	3	90443	PsychophysicsToolbox
# 180.896	0.002	resp	3	90448	PsychophysicsToolbox
# 180.906	0.002	resp	3	90453	PsychophysicsToolbox
# 180.916	0.002	resp	3	90458	PsychophysicsToolbox
# 180.926	0.002	resp	3	90463	PsychophysicsToolbox
# 181.432	0.002	stim_on	4	90716	PsychophysicsToolbox
# 182.358	0.002	resp	3	91179	PsychophysicsToolbox
# 182.376	0.002	resp	3	91188	PsychophysicsToolbox
# 182.386	0.002	resp	3	91193	PsychophysicsToolbox
# 182.396	0.002	resp	3	91198	PsychophysicsToolbox
# 182.406	0.002	resp	3	91203	PsychophysicsToolbox
# 182.416	0.002	resp	3	91208	PsychophysicsToolbox
# 182.426	0.002	resp	3	91213	PsychophysicsToolbox
# 182.436	0.002	resp	3	91218	PsychophysicsToolbox
# 182.452	0.002	resp	3	91226	PsychophysicsToolbox
# 182.462	0.002	resp	3	91231	PsychophysicsToolbox
# 182.472	0.002	resp	3	91236	PsychophysicsToolbox
# 182.482	0.002	resp	3	91241	PsychophysicsToolbox
# 183.12	0.002	stim_on	4	91560	PsychophysicsToolbox
# 184.166	0.002	resp	3	92083	PsychophysicsToolbox
# 184.184	0.002	resp	3	92092	PsychophysicsToolbox
# 184.194	0.002	resp	3	92097	PsychophysicsToolbox
# 184.204	0.002	resp	3	92102	PsychophysicsToolbox
# 184.22	0.002	resp	3	92110	PsychophysicsToolbox
# 184.23	0.002	resp	3	92115	PsychophysicsToolbox
# 184.24	0.002	resp	3	92120	PsychophysicsToolbox
# 184.25	0.002	resp	3	92125	PsychophysicsToolbox
# 184.26	0.002	resp	3	92130	PsychophysicsToolbox
# 184.27	0.002	resp	3	92135	PsychophysicsToolbox
# 184.28	0.002	resp	3	92140	PsychophysicsToolbox
# 184.472	0.002	stim_on	4	92236	PsychophysicsToolbox
# 185.462	0.002	resp	3	92731	PsychophysicsToolbox
# 185.474	0.002	resp	3	92737	PsychophysicsToolbox
# 185.49	0.002	resp	3	92745	PsychophysicsToolbox
# 185.5	0.002	resp	3	92750	PsychophysicsToolbox
# 185.51	0.002	resp	3	92755	PsychophysicsToolbox
# 185.52	0.002	resp	3	92760	PsychophysicsToolbox
# 185.53	0.002	resp	3	92765	PsychophysicsToolbox
# 185.54	0.002	resp	3	92770	PsychophysicsToolbox
# 185.55	0.002	resp	3	92775	PsychophysicsToolbox
# 185.56	0.002	resp	3	92780	PsychophysicsToolbox
# 185.858	0.002	stim_on	4	92929	PsychophysicsToolbox
# 186.954	0.002	resp	3	93477	PsychophysicsToolbox
# 186.972	0.002	resp	3	93486	PsychophysicsToolbox
# 186.982	0.002	resp	3	93491	PsychophysicsToolbox
# 186.992	0.002	resp	3	93496	PsychophysicsToolbox
# 187.002	0.002	resp	3	93501	PsychophysicsToolbox
# 187.012	0.002	resp	3	93506	PsychophysicsToolbox
# 187.028	0.002	resp	3	93514	PsychophysicsToolbox
# 187.038	0.002	resp	3	93519	PsychophysicsToolbox
# 187.048	0.002	resp	3	93524	PsychophysicsToolbox
# 187.058	0.002	resp	3	93529	PsychophysicsToolbox
# 187.068	0.002	resp	3	93534	PsychophysicsToolbox
# 187.078	0.002	resp	3	93539	PsychophysicsToolbox
# 187.21	0.002	stim_on	4	93605	PsychophysicsToolbox
# 188.204	0.002	resp	3	94102	PsychophysicsToolbox
# 188.218	0.002	resp	3	94109	PsychophysicsToolbox
# 188.228	0.002	resp	3	94114	PsychophysicsToolbox
# 188.238	0.002	resp	3	94119	PsychophysicsToolbox
# 188.248	0.002	resp	3	94124	PsychophysicsToolbox
# 188.258	0.002	resp	3	94129	PsychophysicsToolbox
# 188.268	0.002	resp	3	94134	PsychophysicsToolbox
# 188.278	0.002	resp	3	94139	PsychophysicsToolbox
# 188.288	0.002	resp	3	94144	PsychophysicsToolbox
# 188.298	0.002	resp	3	94149	PsychophysicsToolbox
# 188.308	0.002	resp	3	94154	PsychophysicsToolbox
# 188.318	0.002	resp	3	94159	PsychophysicsToolbox
# 188.714	0.002	stim_on	4	94357	PsychophysicsToolbox
# 189.712	0.002	resp	3	94856	PsychophysicsToolbox
# 189.73	0.002	resp	3	94865	PsychophysicsToolbox
# 189.74	0.002	resp	3	94870	PsychophysicsToolbox
# 189.75	0.002	resp	3	94875	PsychophysicsToolbox
# 189.76	0.002	resp	3	94880	PsychophysicsToolbox
# 189.77	0.002	resp	3	94885	PsychophysicsToolbox
# 189.78	0.002	resp	3	94890	PsychophysicsToolbox
# 189.79	0.002	resp	3	94895	PsychophysicsToolbox
# 189.8	0.002	resp	3	94900	PsychophysicsToolbox
# 189.81	0.002	resp	3	94905	PsychophysicsToolbox
# 189.82	0.002	resp	3	94910	PsychophysicsToolbox
# 189.83	0.002	resp	3	94915	PsychophysicsToolbox
# 189.84	0.002	resp	3	94920	PsychophysicsToolbox
# 190.088	0.002	end	2	95044	PsychophysicsToolbox

# %%
# %cat sub-01/ses-ImageNet01/eeg/sub-01_ses-ImageNet01_task-ImageNet_run-01_events.json
# Out:
# {
#   "onset": {
#     "Description": "Onset (in seconds) of the event from the beginning of the first datapoint. Negative onsets account for events before the first stored data point.",
#     "Units": "s"
#   },
#   "duration": {
#     "Description": "Duration of the event in seconds from onset. Must be zero, positive, or 'n/a' if unavailable. A zero value indicates an impulse event. ",
#     "Units": "s"
#   },
#   "sample": {
#     "Description": "The event onset time in number of sampling points.First sample is 0."
#   },
#   "value": {
#     "Description": "The event code (also known as trigger code or event ID) associated with the event."
#   },
#   "trial_type": {
#     "Description": "The type, category, or name of the event."
#   },
#   "StimulusPresentation": {
#     "ScreenDistance": 0.7,
#     "ScreenResolution": [
#       1024,
#       768
#     ],
#     "ScreenSize": [
#       0.6,
#       0.6
#     ],
#     "SoftwareName": "Psychtoolbox",
#     "SoftwareVersion": "3.0"
#   }
# }

# %%
# display super classes of objects
print(
    epochs.metadata["super_class"]
    .value_counts()
)
# Out:
# super_class
# canine                  520
# device                  496
# container               372
# covering                344
# invertebrate            244
# bird                    236
# structure               228
# food                    152
# equipment               148
# reptile                 144
# implement               144
# artifact                120
# conveyance              116
# furnishing               96
# mammal                   92
# primate                  80
# ungulate                 68
# fish                     64
# fruit                    64
# carnivore                60
# feline                   52
# geological_formation     36
# amphibian                32
# fungus                   28
# toiletry                 24
# person                   12
# abstraction              12
# plant                     8
# bar                       4
# substance                 4
# Name: count, dtype: int64

# %%
# display classes of objects
print(
    epochs.metadata["class"]
    .value_counts()
    .head(20)
)
# Out:
# class
# crane                     8
# maillot                   8
# jean                      4
# bolo tie                  4
# American lobster          4
# binoculars                4
# trimaran                  4
# safe                      4
# red-breasted merganser    4
# projector                 4
# Ibizan hound              4
# Angora                    4
# lumbermill                4
# fire engine               4
# alp                       4
# gar                       4
# bagel                     4
# palace                    4
# cheetah                   4
# bull mastiff              4
# Name: count, dtype: int64

# %%
# plotting epoched data over 4 sessions
epochs.plot()
# Out:
# <mne_qt_browser._pg_figure.MNEQtBrowser(0x109a1a7a0) at 0x45fa43900>

# %%
# plotting animate epochs
animate_epochs = epochs[
    epochs.metadata["stim_is_animate"] == True
]

animate_epochs.plot()
# Out:
# Using qt as 2D backend.
# <mne_qt_browser._pg_figure.MNEQtBrowser(0x125664410) at 0x393256280>

# %%
# plotting inanimate epochs
inanimate_epochs = epochs[
    epochs.metadata["stim_is_animate"] == False
]

inanimate_epochs.plot()
# Out:
# <mne_qt_browser._pg_figure.MNEQtBrowser(0x144cc0a10) at 0x39339a380>

# %%
# creating averaged data
evoked = epochs.average()
evoked
# Out:
# <Evoked | 'stim_on' (average, N=4000), -0.1 – 0.8 s, baseline -0.1 – 0 s, 62 ch, ~186 KiB>

# %%
PO7_evoked = evoked.plot(picks='PO7')
# Out:
# Need more than one channel to make topography for eeg. Disabling interactivity.

# %%
PO5_evoked = evoked.plot(picks='PO5')
# Out:
# Need more than one channel to make topography for eeg. Disabling interactivity.

# %%
PO3_evoked = evoked.plot(picks='PO3')
# Out:
# Need more than one channel to make topography for eeg. Disabling interactivity.

# %%
POz_evoked = evoked.plot(picks='POz')
# Out:
# Need more than one channel to make topography for eeg. Disabling interactivity.

# %%
PO4_evoked = evoked.plot(picks='PO4')
# Out:
# Need more than one channel to make topography for eeg. Disabling interactivity.

# %%
PO6_evoked = evoked.plot(picks='PO6')
# Out:
# Need more than one channel to make topography for eeg. Disabling interactivity.

# %%
PO8_evoked = evoked.plot(picks='PO8')
# Out:
# Need more than one channel to make topography for eeg. Disabling interactivity.

# %%
O1_evoked = evoked.plot(picks='O1')
# Out:
# Need more than one channel to make topography for eeg. Disabling interactivity.

# %%
Oz_evoked = evoked.plot(picks='Oz')
# Out:
# Need more than one channel to make topography for eeg. Disabling interactivity.

# %%
O2_evoked = evoked.plot(picks='O2')
# Out:
# Need more than one channel to make topography for eeg. Disabling interactivity.

# %%
occipital = ['PO7', 'PO5', 'PO3', 'POz', 'PO4', 'PO6', 'PO8', 'O1', 'Oz', 'O2']
occipital_evoked = evoked.plot(picks=occipital)

# %%
evoked.plot();

# %%
animate_evoked = animate_epochs.average()
animate_evoked
# Out:
# <Evoked | 'stim_on' (average, N=1640), -0.1 – 0.8 s, baseline -0.1 – 0 s, 62 ch, ~186 KiB>

# %%
inanimate_evoked = inanimate_epochs.average()
inanimate_evoked
# Out:
# <Evoked | 'stim_on' (average, N=2360), -0.1 – 0.8 s, baseline -0.1 – 0 s, 62 ch, ~186 KiB>

# %%
mne.viz.plot_compare_evokeds(
    {
        "Animate": animate_evoked,
        "Inanimate": inanimate_evoked
    }
)
# Out:
# combining channels using GFP (eeg channels)
# combining channels using GFP (eeg channels)
# [<Figure size 800x600 with 1 Axes>]

# %%
mne.viz.plot_compare_evokeds(
    {
        "Animate": animate_evoked,
        "Inanimate": inanimate_evoked
    },
    picks=occipital
)
# Out:
# More than 6 channels, truncating title ...
# combining channels using GFP (eeg channels)
# combining channels using GFP (eeg channels)
# [<Figure size 800x600 with 1 Axes>]

# %%
mne.viz.plot_compare_evokeds(
    {
        "Animate": animate_evoked,
        "Inanimate": inanimate_evoked
    },
    picks='PO7'
)
# Out:
# [<Figure size 800x600 with 2 Axes>]

# %%
mne.viz.plot_compare_evokeds(
    {
        "Animate": animate_evoked,
        "Inanimate": inanimate_evoked
    },
    picks='PO5'
)
# Out:
# [<Figure size 800x600 with 2 Axes>]

# %%
mne.viz.plot_compare_evokeds(
    {
        "Animate": animate_evoked,
        "Inanimate": inanimate_evoked
    },
    picks='PO3'
)
# Out:
# [<Figure size 800x600 with 2 Axes>]

# %%
mne.viz.plot_compare_evokeds(
    {
        "Animate": animate_evoked,
        "Inanimate": inanimate_evoked
    },
    picks='POz'
)
# Out:
# [<Figure size 800x600 with 2 Axes>]

# %%
mne.viz.plot_compare_evokeds(
    {
        "Animate": animate_evoked,
        "Inanimate": inanimate_evoked
    },
    picks='PO4'
)
# Out:
# [<Figure size 800x600 with 2 Axes>]

# %%
mne.viz.plot_compare_evokeds(
    {
        "Animate": animate_evoked,
        "Inanimate": inanimate_evoked
    },
    picks='PO6'
)
# Out:
# [<Figure size 800x600 with 2 Axes>]

# %%
mne.viz.plot_compare_evokeds(
    {
        "Animate": animate_evoked,
        "Inanimate": inanimate_evoked
    },
    picks='PO8'
)
# Out:
# [<Figure size 800x600 with 2 Axes>]

# %%
mne.viz.plot_compare_evokeds(
    {
        "Animate": animate_evoked,
        "Inanimate": inanimate_evoked
    },
    picks='O1'
)
# Out:
# [<Figure size 800x600 with 2 Axes>]

# %%
mne.viz.plot_compare_evokeds(
    {
        "Animate": animate_evoked,
        "Inanimate": inanimate_evoked
    },
    picks='Oz'
)
# Out:
# [<Figure size 800x600 with 2 Axes>]

# %%
mne.viz.plot_compare_evokeds(
    {
        "Animate": animate_evoked,
        "Inanimate": inanimate_evoked
    },
    picks='O2'
)
# Out:
# [<Figure size 800x600 with 2 Axes>]

# %%
# plotting difference waves
diff = animate_evoked.copy()
diff.data = animate_evoked.data - inanimate_evoked.data

diff.plot(picks=occipital);

# %%
animate_evoked.plot_topomap(
    times=[0.1, 0.17, 0.25, 0.4]
)

# %%
inanimate_evoked.plot_topomap(
    times=[0.1, 0.17, 0.25, 0.4]
)

# %%
power.plot(picks=occipital)
# Out:
# No baseline correction applied
# [<Figure size 640x480 with 2 Axes>,
#  <Figure size 640x480 with 2 Axes>,
#  <Figure size 640x480 with 2 Axes>,
#  <Figure size 640x480 with 2 Axes>,
#  <Figure size 640x480 with 2 Axes>,
#  <Figure size 640x480 with 2 Axes>,
#  <Figure size 640x480 with 2 Axes>,
#  <Figure size 640x480 with 2 Axes>,
#  <Figure size 640x480 with 2 Axes>,
#  <Figure size 640x480 with 2 Axes>]

# %%
animate_mean = animate_epochs.copy().crop(
    tmin=0.25, tmax=0.35
).get_data(picks="Oz").mean(axis=(1, 2))

inanimate_mean = inanimate_epochs.copy().crop(
    tmin=0.25, tmax=0.35
).get_data(picks="Oz").mean(axis=(1, 2))

print(np.mean(animate_mean))
print(np.mean(inanimate_mean))

# %%
animate_evoked.plot_joint()

# %%
animate_mean = (
    animate_epochs
    .copy()
    .crop(0.25, 0.35)
    .get_data(picks=occipital)
    .mean(axis=(1,2))
)

inanimate_mean = (
    inanimate_epochs
    .copy()
    .crop(0.25, 0.35)
    .get_data(picks=occipital)
    .mean(axis=(1,2))
)

print(animate_mean.mean() * 1e6)
print(inanimate_mean.mean() * 1e6)

# %%
superclasses = [
    "canine",
    "device",
    "container",
    "covering",
    "invertebrate",
    "bird",
    "structure",
    "food"
]

evokeds = {}

for sc in superclasses:
    subset = epochs[
        epochs.metadata["super_class"] == sc
    ]

    evokeds[sc] = subset.average()

mne.viz.plot_compare_evokeds(
    evokeds,
    picks="Oz"
)
